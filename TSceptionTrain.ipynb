# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# 'Colab Notebooks'   exercise-master   TSception

# %%
#This is a script to do pre-processing on the EEG data
import numpy as np
import math
import h5py
import os
from pathlib import Path
class Processer:
    def __init__(self):
        self.data = None
        self.label = None
        self.data_processed = None
        self.label_processed = None   
    def load_data(self, path, subject):
        path = Path(path)
        data_list = []
        label_list = []
        for i in range(subject):
            file_code = 'sub_'+ str(i)+'.hdf'
            file = path / file_code
            data_dictionary = h5py.File(file, 'r')
            data = data_dictionary['data']
            label = data_dictionary['label']
            data_list.append(data)
            label_list.append(label)
            print('The shape of data is:'+ str(data_list[-1].shape))
            print('The shape of label is:' + str(label_list[-1].shape))
        self.data = np.stack(data_list, axis = 0)
        self.label = np.stack(label_list, axis = 0)
        # data: subject x trial x channels x datapoint
        # label: subject x trial x datapoint
        print('***************Data loaded successfully!***************')
       
    def format_data(self):
        # data: subject x trial x channels x datapoint
        # label: subject x trial x datapoint
        data = self.data
        label = self.label

        # change the label representation 1.0 -> 0.0; 2.0 -> 1.0
        label[label == 1.0] = 0.0
        label[label == 2.0] = 1.0
        
        #Expand the frequency dimention
        self.data_processed = np.expand_dims(data, axis = 2)       

        self.label_processed = label
        
        print("The data shape is:" + str(self.data_processed.shape))
        
    def split_data(self, segment_length = 1, overlap = 0, sampling_rate = 256, save = False):
        #data: subject x trial x 1 x channels x datapoint
        #label: subject x trial x datapoint
        #Parameters
        data = self.data_processed
        label = self.label_processed
        #Split the data given
        data_shape = data.shape
        label_shape = label.shape
        data_step = int(segment_length * sampling_rate * (1 - overlap))
        data_segment = sampling_rate * segment_length
        data_split = []
        label_split = []
        
        number_segment = int((label_shape[2]-data_segment)//(data_step)) + 1
        for i in range(number_segment):
            data_split.append(data[:,:,:,:,(i * data_step):(i * data_step + data_segment)])
            label_split.append(label[:,:,(i * data_step)])
        data_split_array = np.stack(data_split, axis = 2)
        label_split_array = np.stack(label_split, axis = 2)
        print("The data and label are splited: Data shape:" + str(data_split_array.shape) +" Label:" + str(label_split_array.shape))
        self.data_processed = data_split_array
        self.label_processed = label_split_array
        

        #TODO: Save the processed data here
        if save == True:
            if self.data_processed.all() != None:
              
              save_path = Path(os.getcwd())
              filename_data = save_path / Path('data_split.hdf')
              save_data = h5py.File(filename_data, 'w')
              save_data['data'] = self.data_processed
              save_data['label'] = self.label_processed
              save_data.close()
              print("Data and Label saved successfully! at: " + str(filename_data))
            else :
              print("data_splited is None")
        
    def getValue(self):
      data = self.data_processed
      return data
    def getLabelValue(self):
      label = self.label_processed
      return label

        
if __name__ == "__main__":
    Pro = Processer() 
    # e.g. path = '/Users/mac/TSception/data'
    Pro.load_data(path=("/content/drive/My Drive/TSception"),subject=15) 
    Pro.format_data()      
    Pro.split_data(segment_length = 4, overlap = 0.975, sampling_rate = 256, save = False)
    getData = Pro.getValue()
    getLabel = Pro.getLabelValue()
# Out:
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# The shape of data is:(10, 4, 15000)
# The shape of label is:(10, 15000)
# ***************Data loaded successfully!***************
# The data shape is:(15, 10, 1, 4, 15000)
# The data and label are splited: Data shape:(15, 10, 560, 1, 4, 1024) Label:(15, 10, 560)

# %% [markdown]
# 我们上面利用返回值就不用再将数据存储和再次读取了，我们先导入EEGDataset

# %%
import torch
from torch.utils.data import Dataset, TensorDataset

class EEGDataset(Dataset):
    # x_tensor: (sample, channel, datapoint(feature)) type = torch.tensor
    # y_tensor: (sample,) type = torch.tensor
    
    def __init__(self, x_tensor, y_tensor):
        
        self.x = x_tensor
        self.y = y_tensor
        
        assert self.x.size(0) == self.y.size(0)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.y)

# %% [markdown]
# 再次导入TSception模型

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

'''
This is the models of TSception and its variant

To use the models, please manage the data into
the dimension of(mini-batch, 1, EEG-channels,data point)
before feed the data into forward()

For more details about the models, please refer to our paper:

Yi Ding, Neethu Robinson, Qiuhao Zeng, Dou Chen, Aung Aung Phyo Wai, Tih-Shih Lee, Cuntai Guan,
"TSception: A Deep Learning Framework for Emotion Detection Useing EEG"(IJCNN 2020)

'''

    
################################################## TSception ######################################################
class TSception(nn.Module):
    def __init__(self, num_classes, input_size, sampling_rate, num_T, num_S, hiden, dropout_rate):
        # input_size: EEG channel x datapoint
        super(TSception, self).__init__()
        self.inception_window = [0.5, 0.25, 0.125, 0.0625, 0.03125]
        # by setting the convolutional kernel being (1,lenght) and the strids being 1 we can use conv2d to
        # achieve the 1d convolution operation
        self.Tception1 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[0]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        self.Tception2 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[1]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        self.Tception3 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[2]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        
        self.Sception1 = nn.Sequential(
            nn.Conv2d(num_T, num_S, kernel_size=(int(input_size[0]),1), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,8), stride=(1,8)))
        self.Sception2 = nn.Sequential(
            nn.Conv2d(num_T, num_S, kernel_size=(int(input_size[0]*0.5),1), stride=(int(input_size[0]*0.5),1), padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,8), stride=(1,8)))

        self.BN_t = nn.BatchNorm2d(num_T)
        self.BN_s = nn.BatchNorm2d(num_S)
        size = self.get_size(input_size)
        
        self.fc1 = nn.Sequential(
            nn.Linear(size[1], hiden),
            nn.ReLU(),
            nn.Dropout(dropout_rate))
        self.fc2 = nn.Sequential(
            nn.Linear(hiden, num_classes),
            nn.LogSoftmax())
    def forward(self, x):
        y = self.Tception1(x)
        out = y
        y = self.Tception2(x)
        out = torch.cat((out,y),dim = -1)
        y = self.Tception3(x)
        out = torch.cat((out,y),dim = -1)
        out = self.BN_t(out)
        z = self.Sception1(out)        
        out_final = z
        z = self.Sception2(out)
        out_final = torch.cat((out_final,z),dim = 2)
        out = self.BN_s(out_final)
        out = out.view(out.size()[0], -1)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

    def get_size(self,input_size):
        # here we use and array with the shape being
        # (1(mini-batch),1(convolutional channel),EEG channel,time data point)
        # to simulate the input data and get the output size
        data = torch.ones((1,1,input_size[0],input_size[1]))

        y = self.Tception1(data)
        out = y
        y = self.Tception2(data)
        out = torch.cat((out,y),dim = -1)
        y = self.Tception3(data)
        out = torch.cat((out,y),dim = -1)
        out = self.BN_t(out)
        z = self.Sception1(out)        
        out_final = z
        z = self.Sception2(out)
        out_final = torch.cat((out_final,z),dim = 2)
        out = self.BN_s(out_final)
        out = out.view(out.size()[0], -1)
        return out.size()
######################################### Temporal ########################################
class Tception(nn.Module):
    def __init__(self, num_classes, input_size, sampling_rate, num_T, hiden, dropout_rate):
        # input_size: channel x datapoint
        super(Tception, self).__init__()
        self.inception_window = [0.5, 0.25, 0.125, 0.0625, 0.03125]
        # by setting the convolutional kernel being (1,lenght) and the strids being 1 we can use conv2d to
        # achieve the 1d convolution operation
        self.Tception1 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[0]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        self.Tception2 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[1]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        self.Tception3 = nn.Sequential(
            nn.Conv2d(1, num_T, kernel_size=(1,int(self.inception_window[2]*sampling_rate)), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        
        self.BN_t = nn.BatchNorm2d(num_T)

        size = self.get_size(input_size,sampling_rate,num_T)
        self.fc1 = nn.Sequential(
            nn.Linear(size[1], hiden),
            nn.ReLU(),
            nn.Dropout(dropout_rate))
        self.fc2 = nn.Sequential(
            nn.Linear(hiden, num_classes),
            nn.LogSoftmax())
    def forward(self, x):
        y = self.Tception1(x)
        out = y
        y = self.Tception2(x)
        out = torch.cat((out,y),dim = -1)
        y = self.Tception3(x)
        out = torch.cat((out,y),dim = -1)
        out = self.BN_t(out)
        out = out.view(out.size()[0], -1)
        out = self.fc1(out)
        out = self.fc2(out)
        return out
    def get_size(self,input_size,sampling_rate,num_T):
        data = torch.ones((1,1,input_size[0],input_size[1]))        
        y = self.Tception1(data)
        out = y
        y = self.Tception2(data)
        out = torch.cat((out,y),dim = -1)
        y = self.Tception3(data)
        out = torch.cat((out,y),dim = -1)
        out = self.BN_t(out)
        out = out.view(out.size()[0], -1)
        return out.size()
    
############################################ Spacial ########################################  
class Sception(nn.Module):
    def __init__(self, num_classes, input_size, sampling_rate, num_S, hiden, dropout_rate):
        # input_size: channel x datapoint
        super(Sception, self).__init__()
        
        self.Sception1 = nn.Sequential(
            nn.Conv2d(1, num_S, kernel_size=(int(input_size[0]),1), stride=1, padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))
        self.Sception2 = nn.Sequential(
            nn.Conv2d(1, num_S, kernel_size=(int(input_size[0]*0.5),1), stride=(int(input_size[0]*0.5),1), padding=0),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(1,16), stride=(1,16)))

        self.BN_s = nn.BatchNorm2d(num_S)
        
        size = self.get_size(input_size)
        
        self.fc1 = nn.Sequential(
            nn.Linear(size[1], hiden),
            nn.ReLU(),
            nn.Dropout(dropout_rate))
        self.fc2 = nn.Sequential(
            nn.Linear(hiden, num_classes),
            nn.LogSoftmax())
        
    def forward(self, x):
        y = self.Sception1(x)
        out = y
        y = self.Sception2(x)
        out = torch.cat((out,y),dim = 2)
        out = self.BN_s(out)
        out = out.view(out.size()[0], -1)
        out = self.fc1(out)
        out = self.fc2(out)
        return out
    def get_size(self, input_size):
        data = torch.ones((1,1,input_size[0],input_size[1]))
        y = self.Sception1(data)
        out = y
        y = self.Sception2(data)
        out = torch.cat((out,y),dim = 2)
        out = self.BN_s(out)
        out = out.view(out.size()[0], -1)
        return out.size()

if __name__ == "__main__":
    model = TSception(2,(4,1024),256,9,6,128,0.2)
    #model = Sception(2,(4,1024),256,6,128,0.2)
    #model = Tception(2,(4,1024),256,9,128,0.2)
    print(model)
    pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(pytorch_total_params)
# Out:
# TSception(
#   (Tception1): Sequential(
#     (0): Conv2d(1, 9, kernel_size=(1, 128), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=(1, 16), stride=(1, 16), padding=0)
#   )
#   (Tception2): Sequential(
#     (0): Conv2d(1, 9, kernel_size=(1, 64), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=(1, 16), stride=(1, 16), padding=0)
#   )
#   (Tception3): Sequential(
#     (0): Conv2d(1, 9, kernel_size=(1, 32), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=(1, 16), stride=(1, 16), padding=0)
#   )
#   (Sception1): Sequential(
#     (0): Conv2d(9, 6, kernel_size=(4, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#   )
#   (Sception2): Sequential(
#     (0): Conv2d(9, 6, kernel_size=(2, 1), stride=(2, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#   )
#   (BN_t): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_s): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Sequential(
#     (0): Linear(in_features=396, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=128, out_features=2, bias=True)
#     (1): LogSoftmax(dim=None)
#   )
# )
# 53483

# %% [markdown]
# 导入数据，然后用于训练

# %%
import torch
import time
import numpy as np
import h5py
import datetime
import os
import torch.nn as nn

from pathlib import Path
#from EEGDataset import *
from torch.utils.data import DataLoader
#from Models import *

# Acknowledgement:
# Thanks to this tutorial:
# [https://colab.research.google.com/github/dvgodoy/PyTorch101_ODSC_London2019/blob/master/PyTorch101_Colab.ipynb]
class TrainModel():
    def __init__(self):
        self.data = None
        self.label = None
        self.result = None
        self.input_shape = None # should be (eeg_channel, time data point)
        self.model = 'TSception'
        self.cross_validation = 'Session' # Subject
        self.sampling_rate = 256
        
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        # Parameters: Training process
        self.random_seed = 42
        self.learning_rate = 1e-3
        self.num_epochs = 200
        self.num_class = 2
        self.batch_size = 128
        self.patient = 4
        
        # Parameters: Model
        self.dropout = 0.3
        self.hiden_node = 128
        self.T = 9
        self.S = 6
        self.Lambda = 1e-6
        
    def load_data(self):
        '''
        This is the function to load the data
        Data format : .hdf
        Input : path
                the path of your data
                type = string
        Data dimension : (subject x trials x segments x 1 x channel x data) type = numpy.array
        Label dimension : (subject x trials x segments) type = numpy.array
        Note : For different data formats, please change the loading
               functions, (e.g. use h5py.File to load NAME.hdf)
               
        '''
        #path = Path(path)
        #dataset = h5py.File(path, 'r')
        self.data = getData
        self.label = getLabel

        # The input_shape should be (channel x data)
        self.input_shape = self.data[0,0,0,0].shape
        
        print('Data loaded!\n Data shape:[{}], Label shape:[{}]'
              .format(self.data.shape,self.label.shape))
        
    def set_parameter(self, cv, model, number_class, sampling_rate,
                      random_seed, learning_rate, epoch, batch_size,
                      dropout, hiden_node, patient,
                      num_T, num_S, Lambda):
        '''
        This is the function to set the parameters of training process and model
        All the settings will be saved into a NAME.txt file 
        Input : cv --
                   The cross-validation type
                   Type = string
                   Default : Leave_one_session_out
                   Note : for different cross validation type, please add the
                          corresponding cross validation function. (e.g. self.Leave_one_session_out())
                          
                model --
                   The model you want choose
                   Type = string
                   Default : TSception
                   
                number_class --
                   The number of classes
                   Type = int
                   Default : 2

                sampling_rate --
                   The sampling rate of the EEG data
                   Type = int
                   Default : 256

                random_seed --
                   The random seed
                   Type : int
                   Default : 42

                learning_rate --
                   Learning rate
                   Type : flaot
                   Default : 0.001

                epoch --
                   Type : int
                   Default : 200

                batch_size --
                   The size of mini-batch
                   Type : int
                   Default : 128
                
                dropout --
                   dropout rate of the fully connected layers
                   Type : float
                   Default : 0.3

                hiden_node --
                   The number of hiden node in the fully connected layer
                   Type : int
                   Default : 128

                patient --
                   How many epoches the training process should wait for
                   It is used for the early-stopping
                   Type : int
                   Default : 4
                   
                num_T --
                   The number of T kernels
                   Type : int
                   Default : 9
                   
                num_S --
                   The number of S kernels
                   Type : int
                   Default : 6

                Lambda --
                   The L1 regulation coefficient in loss function
                   Type : float
                   Default : 1e-6
                
        '''
        self.model = model
        self.sampling_rate = sampling_rate
        # Parameters: Training process
        self.random_seed = random_seed
        self.learning_rate = learning_rate
        self.num_epochs = epoch
        self.num_class = number_class
        self.batch_size = batch_size
        self.patient = patient
        self.Lambda = Lambda
        
        # Parameters: Model
        self.dropout = dropout
        self.hiden_node = hiden_node
        self.T = num_T
        self.S = num_S

        
        #Save to log file for checking
        if cv == "Leave_one_subject_out":
            file = open("result_subject.txt",'a')
        elif cv == "Leave_one_session_out":
            file = open("result_session.txt",'a')
        elif cv == "K_fold":
            file = open("result_k_fold.txt",'a')
        file.write("\n"+ str(datetime.datetime.now())+
              "\nTrain:Parameter setting for " + str(self.model) +
              "\n1)number_class:" + str(self.num_class) + "\n2)random_seed:" + str(self.random_seed)+
              "\n3)learning_rate:" + str(self.learning_rate) + "\n4)num_epochs:" + str(self.num_epochs) +
              "\n5)batch_size:" + str(self.batch_size)+
              "\n6)dropout:" + str(self.dropout) + "\n7)sampling_rate:" + str(self.sampling_rate) +
              "\n8)hiden_node:" + str(self.hiden_node) + "\n9)input_shape:" + str(self.input_shape) +
              "\n10)patient:" + str(self.patient) + "\n11)T:" + str(self.T) + 
              "\n12)S:" + str(self.S) + "\n13)Lambda:" + str(self.Lambda) + '\n')
        
        file.close()

    def Leave_one_session_out(self):
        '''
        This is the function to achieve 'Leave one session out' cross-validation
        To know more details about 'Leave one session out', please refer to our paper

        Note : all the acc and std will be logged into the result_session.txt
               
               The txt file is located at the same location as the python script
        
        '''
        save_path = Path(os.getcwd())
        if not os.path.exists(save_path / Path('Result_model/Leave_one_session_out/history')):
            os.makedirs(save_path / Path('Result_model/Leave_one_session_out/history'))
        #Data dimension: subject x trials x segments x 1 x channel x data
        #Label dimension: subject x trials x segments
        #Session: trials[0:2]-session 1; trials[2:4]-session 2; trials[4:end]-session 3
        data = self.data
        label = self.label
        shape_data = data.shape
        shape_label = label.shape
        subject = shape_data[0]
        trial = shape_data[1]
        session = int(shape_data[1]/2)
        channel = shape_data[4]
        frequency = shape_data[3]
        print("Train:Leave_one_session_out \n1)shape of data:" + str(shape_data) + " \n2)shape of label:" + str(shape_label)+
              " \n3)trials:" + str(trial) + " \n4)session:" + str(session) +
              " \n5)datapoint:" + str(frequency) + " \n6)channel:" + str(channel))
        #Train and evaluate the model subject by subject
        ACC = []
        ACC_mean = []
        for i in range(subject):
            index = np.arange(trial)
            ACC_subject = []
            ACC_session = []
            for j in range(session):
                # Split the data into training set and test set
                # One session(contains 2 trials) is test set
                # The rest are training set
                index_train = np.delete(index,[2*j,2*j+1])
                index_test = index[2*j:2*(j+1)]

                data_train = data[i,index_train,:,:,:,:]
                label_train = label[i,index_train,:]

                data_test = data[i,index_test,:,:,:,:]
                label_test = label[i,index_test,:]

                # Split the training set into training set and validation set
                data_train,label_train, data_val, label_val = self.split(data_train, label_train)
                
                # Prepare the data format for training the model
                data_train = torch.from_numpy(data_train).float()
                label_train = torch.from_numpy(label_train).long()

                data_val = torch.from_numpy(data_val).float()
                label_val = torch.from_numpy(label_val).long()
                

                data_test = torch.from_numpy(np.concatenate(data_test, axis = 0)).float()
                label_test = torch.from_numpy(np.concatenate(label_test, axis = 0)).long()
                
                # Check the dimension of the training, validation and test set
                print('Training:', data_train.size(), label_train.size())
                print('Validation:', data_val.size(), label_val.size())
                print('Test:', data_test.size(), label_test.size())

                # Get the accuracy of the model
                ACC_session = self.train(data_train,label_train,
                                         data_test,label_test,
                                         data_val, label_val,
                                         subject = i, session = j,
                                         cv_type = "leave_one_session_out")
                
                ACC_subject.append(ACC_session)
                '''
                # Log the results per session
                
                file = open("result_session.txt",'a')
                file.write('Subject:'+str(i) +' Session:'+ str(j) + ' ACC:' + str(ACC_session) + '\n')
                file.close()
                '''
            ACC_subject = np.array(ACC_subject)
            mAcc = np.mean(ACC_subject)
            std = np.std(ACC_subject)
            
            print("Subject:" + str(i) + "\nmACC: %.2f" % mAcc)
            print("std: %.2f" % std)

            # Log the results per subject
            file = open("result_session.txt",'a')
            file.write('Subject:'+str(i) +' MeanACC:'+ str(mAcc) + ' Std:' + str(std) + '\n')
            file.close()
        
            ACC.append(ACC_subject)
            ACC_mean.append(mAcc)

        self.result = ACC
        # Log the final Acc and std of all the subjects
        file = open("result_session.txt",'a')
        file.write("\n"+ str(datetime.datetime.now()) +'\nMeanACC:'+ str(np.mean(ACC_mean)) + ' Std:' + str(np.std(ACC_mean)) + '\n')
        file.close()
        print("Mean ACC:" + str(np.mean(ACC_mean)) + ' Std:' + str(np.std(ACC_mean)))

        # Save the result
        save_path = Path(os.getcwd())
        filename_data = save_path / Path('Result_model/Result.hdf')
        save_data = h5py.File(filename_data, 'w')
        save_data['result'] = self.result
        save_data.close()
        
    def split(self, data, label):
        '''
        This is the function to split the training set into training set and validation set
        Input : data --
                The training data
                Dimension : trials x segments x 1 x channel x data
                Type : np.array
                
                label --
                The label of training data
                Dimension : trials x segments
                Type : np.array
                
        Output : train --
                 The split training data
                 Dimension : trials x segments x 1 x channel x data
                 Type : np.array

                 train_label --
                 The corresponding label of split training data
                 Dimension : trials x segments
                 Type : np.array

                 val --
                 The split validation data
                 Dimension : trials x segments x 1 x channel x data
                 Type : np.array

                 val_label --
                 The corresponding label of split validation data
                 Dimension : trials x segments
                 Type : np.array
        '''
        #Data dimension: trials x segments x 1 x channel x data
        #Label dimension: trials x segments
        np.random.seed(0)
        data = np.concatenate(data, axis = 0)
        label = np.concatenate(label, axis = 0)
        #data : segments x 1 x channel x data
        #label : segments
        index = np.arange(data.shape[0])
        index_randm = index
        np.random.shuffle(index_randm)
        label = label[index_randm]
        data = data[index_randm]

        # get validation set
        val = data[int(data.shape[0]*0.8):]
        val_label = label[int(data.shape[0]*0.8):]

        train = data[0:int(data.shape[0]*0.8)]
        train_label = label[0:int(data.shape[0]*0.8)]

        return train, train_label, val, val_label
    
    def make_train_step(self, model, loss_fn, optimizer):
        def train_step(x,y):
            model.train()
            yhat = model(x)
            pred = yhat.max(1)[1]
            correct = (pred == y).sum()
            acc = correct.item() / len(pred)
            # L1 regularization
            loss_r = self.regulization(model,self.Lambda)
            # yhat is in one-hot representation;
            loss = loss_fn(yhat, y) + loss_r
            #loss = loss_fn(yhat, y)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            return loss.item(), acc
        return train_step

    def regulization(self, model, Lambda):
        w = torch.cat([x.view(-1) for x in model.parameters()])
        err = Lambda * torch.sum(torch.abs(w))
        return err
    
    def train(self, train_data, train_label, test_data, test_label, val_data,
              val_label, subject, session, cv_type):
        print('Avaliable device:' + str(torch.cuda.get_device_name(torch.cuda.current_device())))
        torch.manual_seed(self.random_seed)
        torch.backends.cudnn.deterministic = True
        # Train and validation loss
        losses = []
        accs = []
        
        Acc_val = []
        Loss_val = []
        val_losses = []
        val_acc = []
        
        test_losses = []
        test_acc = []
        Acc_test = []
        
        # hyper-parameter
        learning_rate = self.learning_rate
        num_epochs = self.num_epochs

        # build the model
        if self.model == 'Sception':
            model = Sception(num_classes = self.num_class, input_size = self.input_shape,
                             sampling_rate = self.sampling_rate, num_S = self.S,
                             hiden = self.hiden_node, dropout_rate = self.dropout)
        elif self.model == 'Tception':
            model = Tception(num_classes = self.num_class, input_size = self.input_shape,
                             sampling_rate = self.sampling_rate, num_T = self.T,
                             hiden = self.hiden_node, dropout_rate = self.dropout)
        elif self.model == 'TSception':
            model = TSception(num_classes = self.num_class, input_size = self.input_shape,
                              sampling_rate = self.sampling_rate, num_T = self.T, num_S = self.S,
                              hiden = self.hiden_node, dropout_rate = self.dropout)
            
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        
        loss_fn = nn.CrossEntropyLoss()

        if torch.cuda.is_available():
            model = model.to(self.device)
            loss_fn = loss_fn.to(self.device)


        train_step = self.make_train_step(model, loss_fn, optimizer)

        # load the data 
        dataset_train = EEGDataset(train_data, train_label)
        dataset_test = EEGDataset(test_data, test_label)
        dataset_val = EEGDataset(val_data, val_label)
        
        # Dataloader for training process
        train_loader = DataLoader(dataset = dataset_train, batch_size = self.batch_size, shuffle = True,pin_memory = False)
        
        val_loader = DataLoader(dataset = dataset_val, batch_size = self.batch_size, pin_memory = False)
        
        test_loader = DataLoader(dataset = dataset_test, batch_size = self.batch_size, pin_memory = False)
        
        total_step = len(train_loader)

        
        ######## Training process ########
        Acc = []
        acc_max = 0
        patient = 0

        for epoch in range(num_epochs):
            loss_epoch = []
            acc_epoch = []
            for i, (x_batch,y_batch) in enumerate(train_loader):
                
                x_batch = x_batch.to(self.device)
                y_batch = y_batch.to(self.device)
                

                loss, acc = train_step(x_batch,y_batch)
                loss_epoch.append(loss)
                acc_epoch.append(acc)
                
            losses.append(sum(loss_epoch)/len(loss_epoch))
            accs.append(sum(acc_epoch)/len(acc_epoch))
            loss_epoch = []
            acc_epoch = []
            print ('Epoch [{}/{}], Loss: {:.4f}, Acc: {:.4f}' 
                   .format(epoch+1, num_epochs,losses[-1] , accs[-1]))
            

            ######## Validation process ########
            with torch.no_grad():
                for x_val, y_val in val_loader:
                    x_val = x_val.to(self.device)
                    y_val = y_val.to(self.device)

                    model.eval()

                    yhat = model(x_val)
                    pred = yhat.max(1)[1]
                    correct = (pred == y_val).sum()
                    acc = correct.item() / len(pred)
                    val_loss = loss_fn(yhat, y_val)
                    val_losses.append(val_loss.item())
                    val_acc.append(acc)
                    
                Acc_val.append(sum(val_acc)/len(val_acc))
                Loss_val.append(sum(val_losses)/len(val_losses))
                print('Evaluation Loss:{:.4f}, Acc: {:.4f}'
                  .format(Loss_val[-1], Acc_val[-1]))
                val_losses = []
                val_acc = []

            ######## early stop ########
            Acc_es = Acc_val[-1]
             
            if Acc_es > acc_max:
                acc_max = Acc_es
                patient = 0
                print('----Model saved!----')
                torch.save(model,'max_model.pt')
            else :
                patient += 1
            if patient > self.patient:
                print('----Early stopping----')
                break
            
             
        ######## test process ########
        model = torch.load('max_model.pt')
        with torch.no_grad(): 
            for x_test, y_test in test_loader:
            
                x_test = x_test.to(self.device)
                y_test = y_test.to(self.device)

                model.eval()

                yhat = model(x_test)
                pred = yhat.max(1)[1]
                correct = (pred == y_test).sum()
                acc = correct.item() / len(pred)
                test_loss = loss_fn(yhat, y_test)
                test_losses.append(test_loss.item())
                test_acc.append(acc)
                
            print('Test Loss:{:.4f}, Acc: {:.4f}'
                  .format(sum(test_losses)/len(test_losses), sum(test_acc)/len(test_acc)))
            Acc_test = (sum(test_acc)/len(test_acc))
            test_losses = []
            test_acc = []
        # save the loss(acc) for plotting the loss(acc) curve
        save_path = Path(os.getcwd())
        if cv_type == "leave_one_session_out":
            filename_callback = save_path / Path('Result_model/Leave_one_session_out/history/'
                                                 + 'history_subject_' + str(subject) + '_session_'
                                                 + str(session)+ '_history.hdf')
            save_history = h5py.File(filename_callback, 'w')
            save_history['acc'] = accs
            save_history['val_acc'] = Acc_val
            save_history['loss'] = losses
            save_history['val_loss'] = Loss_val
            save_history.close()
        return Acc_test
    
if __name__ == "__main__":
    train = TrainModel()
    train.load_data()
    # Please set the parameters here. 
    train.set_parameter( cv = 'Leave_one_session_out',
                         model = 'TSception',
                         number_class = 2,
                         sampling_rate = 256,
                         random_seed = 42,
                         learning_rate = 0.001,
                         epoch = 200,
                         batch_size = 128,
                         dropout = 0.3,
                         hiden_node = 128,
                         patient = 4,
                         num_T = 9,
                         num_S = 6,
                         Lambda = 0.000001)
    train.Leave_one_session_out()
# Out:
# Data loaded!
#  Data shape:[(15, 10, 560, 1, 4, 1024)], Label shape:[(15, 10, 560)]
# Train:Leave_one_session_out
# 1)shape of data:(15, 10, 560, 1, 4, 1024)
# 2)shape of label:(15, 10, 560)
# 3)trials:10
# 4)session:5
# 5)datapoint:1
# 6)channel:4
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch [1/200], Loss: 0.6423, Acc: 0.6152
# Evaluation Loss:0.5673, Acc: 0.7757
# ----Model saved!----
# Epoch [2/200], Loss: 0.4134, Acc: 0.8044
# Evaluation Loss:0.3296, Acc: 0.8739
# ----Model saved!----
# Epoch [3/200], Loss: 0.2803, Acc: 0.8719
# Evaluation Loss:0.2177, Acc: 0.9174
# ----Model saved!----
# Epoch [4/200], Loss: 0.1848, Acc: 0.9263
# Evaluation Loss:0.2021, Acc: 0.9185
# ----Model saved!----
# Epoch [5/200], Loss: 0.1433, Acc: 0.9434
# Evaluation Loss:0.1090, Acc: 0.9621
# ----Model saved!----
# Epoch [6/200], Loss: 0.0695, Acc: 0.9833
# Evaluation Loss:0.0502, Acc: 0.9888
# ----Model saved!----
# Epoch [7/200], Loss: 0.0366, Acc: 0.9950
# Evaluation Loss:0.0283, Acc: 0.9944
# ----Model saved!----
# Epoch [8/200], Loss: 0.0215, Acc: 0.9958
# Evaluation Loss:0.0127, Acc: 1.0000
# ----Model saved!----
# Epoch [9/200], Loss: 0.0158, Acc: 0.9980
# Evaluation Loss:0.0102, Acc: 0.9989
# Epoch [10/200], Loss: 0.0113, Acc: 0.9992
# Evaluation Loss:0.0075, Acc: 0.9989
# Epoch [11/200], Loss: 0.0089, Acc: 0.9989
# Evaluation Loss:0.0114, Acc: 0.9967
# Epoch [12/200], Loss: 0.0057, Acc: 0.9997
# Evaluation Loss:0.0036, Acc: 1.0000
# Epoch [13/200], Loss: 0.0140, Acc: 0.9969
# Evaluation Loss:0.0209, Acc: 0.9944
# ----Early stopping----
# Test Loss:7.7871, Acc: 0.4178
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5415, Acc: 0.6775
# Evaluation Loss:0.4592, Acc: 0.8348
# ----Model saved!----
# Epoch [2/200], Loss: 0.2593, Acc: 0.8915
# Evaluation Loss:0.1662, Acc: 0.9286
# ----Model saved!----
# Epoch [3/200], Loss: 0.1391, Acc: 0.9417
# Evaluation Loss:0.1065, Acc: 0.9576
# ----Model saved!----
# Epoch [4/200], Loss: 0.0703, Acc: 0.9766
# Evaluation Loss:0.0479, Acc: 0.9877
# ----Model saved!----
# Epoch [5/200], Loss: 0.0330, Acc: 0.9936
# Evaluation Loss:0.0184, Acc: 0.9967
# ----Model saved!----
# Epoch [6/200], Loss: 0.0116, Acc: 0.9992
# Evaluation Loss:0.0071, Acc: 0.9989
# ----Model saved!----
# Epoch [7/200], Loss: 0.0079, Acc: 0.9997
# Evaluation Loss:0.0062, Acc: 0.9989
# Epoch [8/200], Loss: 0.0050, Acc: 0.9997
# Evaluation Loss:0.0038, Acc: 0.9989
# Epoch [9/200], Loss: 0.0041, Acc: 1.0000
# Evaluation Loss:0.0034, Acc: 0.9989
# Epoch [10/200], Loss: 0.0031, Acc: 1.0000
# Evaluation Loss:0.0018, Acc: 1.0000
# ----Model saved!----
# Epoch [11/200], Loss: 0.0044, Acc: 0.9994
# Evaluation Loss:0.0151, Acc: 0.9933
# Epoch [12/200], Loss: 0.0039, Acc: 1.0000
# Evaluation Loss:0.0015, Acc: 1.0000
# Epoch [13/200], Loss: 0.0025, Acc: 1.0000
# Evaluation Loss:0.0013, Acc: 1.0000
# Epoch [14/200], Loss: 0.0021, Acc: 1.0000
# Evaluation Loss:0.0008, Acc: 1.0000
# Epoch [15/200], Loss: 0.0019, Acc: 1.0000
# Evaluation Loss:0.0005, Acc: 1.0000
# ----Early stopping----
# Test Loss:8.6117, Acc: 0.4905
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6041, Acc: 0.6373
# Evaluation Loss:0.5539, Acc: 0.7902
# ----Model saved!----
# Epoch [2/200], Loss: 0.4373, Acc: 0.7958
# Evaluation Loss:0.3646, Acc: 0.8304
# ----Model saved!----
# Epoch [3/200], Loss: 0.2787, Acc: 0.8795
# Evaluation Loss:0.2404, Acc: 0.8750
# ----Model saved!----
# Epoch [4/200], Loss: 0.2115, Acc: 0.9121
# Evaluation Loss:0.1896, Acc: 0.9163
# ----Model saved!----
# Epoch [5/200], Loss: 0.1098, Acc: 0.9640
# Evaluation Loss:0.0808, Acc: 0.9810
# ----Model saved!----
# Epoch [6/200], Loss: 0.0659, Acc: 0.9810
# Evaluation Loss:0.0407, Acc: 0.9944
# ----Model saved!----
# Epoch [7/200], Loss: 0.0442, Acc: 0.9888
# Evaluation Loss:0.0262, Acc: 0.9967
# ----Model saved!----
# Epoch [8/200], Loss: 0.0336, Acc: 0.9911
# Evaluation Loss:0.0148, Acc: 0.9989
# ----Model saved!----
# Epoch [9/200], Loss: 0.0193, Acc: 0.9967
# Evaluation Loss:0.0084, Acc: 0.9989
# Epoch [10/200], Loss: 0.0175, Acc: 0.9961
# Evaluation Loss:0.0083, Acc: 0.9989
# Epoch [11/200], Loss: 0.0097, Acc: 0.9994
# Evaluation Loss:0.0046, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0112, Acc: 0.9980
# Evaluation Loss:0.0495, Acc: 0.9799
# Epoch [13/200], Loss: 0.0100, Acc: 0.9983
# Evaluation Loss:0.0083, Acc: 0.9978
# Epoch [14/200], Loss: 0.0078, Acc: 0.9989
# Evaluation Loss:0.0095, Acc: 0.9978
# Epoch [15/200], Loss: 0.0282, Acc: 0.9914
# Evaluation Loss:0.0928, Acc: 0.9621
# Epoch [16/200], Loss: 0.0208, Acc: 0.9944
# Evaluation Loss:0.0034, Acc: 1.0000
# ----Early stopping----
# Test Loss:1.3875, Acc: 0.6050
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5816, Acc: 0.6657
# Evaluation Loss:0.5047, Acc: 0.7299
# ----Model saved!----
# Epoch [2/200], Loss: 0.3908, Acc: 0.7983
# Evaluation Loss:0.3707, Acc: 0.8158
# ----Model saved!----
# Epoch [3/200], Loss: 0.3167, Acc: 0.8387
# Evaluation Loss:0.3190, Acc: 0.8270
# ----Model saved!----
# Epoch [4/200], Loss: 0.2914, Acc: 0.8482
# Evaluation Loss:0.3086, Acc: 0.8371
# ----Model saved!----
# Epoch [5/200], Loss: 0.2209, Acc: 0.8970
# Evaluation Loss:0.1709, Acc: 0.9319
# ----Model saved!----
# Epoch [6/200], Loss: 0.1692, Acc: 0.9333
# Evaluation Loss:0.1228, Acc: 0.9576
# ----Model saved!----
# Epoch [7/200], Loss: 0.1165, Acc: 0.9562
# Evaluation Loss:0.1335, Acc: 0.9364
# Epoch [8/200], Loss: 0.0999, Acc: 0.9646
# Evaluation Loss:0.0585, Acc: 0.9866
# ----Model saved!----
# Epoch [9/200], Loss: 0.0959, Acc: 0.9590
# Evaluation Loss:0.1018, Acc: 0.9531
# Epoch [10/200], Loss: 0.0837, Acc: 0.9710
# Evaluation Loss:0.0441, Acc: 0.9911
# ----Model saved!----
# Epoch [11/200], Loss: 0.0430, Acc: 0.9886
# Evaluation Loss:0.0449, Acc: 0.9810
# Epoch [12/200], Loss: 0.0240, Acc: 0.9955
# Evaluation Loss:0.0159, Acc: 0.9967
# ----Model saved!----
# Epoch [13/200], Loss: 0.0198, Acc: 0.9961
# Evaluation Loss:0.0151, Acc: 0.9955
# Epoch [14/200], Loss: 0.0204, Acc: 0.9958
# Evaluation Loss:0.0299, Acc: 0.9888
# Epoch [15/200], Loss: 0.0340, Acc: 0.9891
# Evaluation Loss:0.0090, Acc: 0.9989
# ----Model saved!----
# Epoch [16/200], Loss: 0.0217, Acc: 0.9939
# Evaluation Loss:0.0084, Acc: 0.9989
# Epoch [17/200], Loss: 0.0123, Acc: 0.9980
# Evaluation Loss:0.0133, Acc: 0.9944
# Epoch [18/200], Loss: 0.0226, Acc: 0.9927
# Evaluation Loss:0.0055, Acc: 1.0000
# ----Model saved!----
# Epoch [19/200], Loss: 0.0079, Acc: 0.9986
# Evaluation Loss:0.0032, Acc: 1.0000
# Epoch [20/200], Loss: 0.0052, Acc: 0.9994
# Evaluation Loss:0.0114, Acc: 0.9967
# Epoch [21/200], Loss: 0.0073, Acc: 0.9989
# Evaluation Loss:0.0102, Acc: 0.9955
# Epoch [22/200], Loss: 0.0081, Acc: 0.9983
# Evaluation Loss:0.0041, Acc: 1.0000
# Epoch [23/200], Loss: 0.0102, Acc: 0.9980
# Evaluation Loss:0.0056, Acc: 0.9989
# ----Early stopping----
# Test Loss:1.9944, Acc: 0.7156
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5980, Acc: 0.6741
# Evaluation Loss:0.5127, Acc: 0.8382
# ----Model saved!----
# Epoch [2/200], Loss: 0.3588, Acc: 0.8493
# Evaluation Loss:0.2654, Acc: 0.8906
# ----Model saved!----
# Epoch [3/200], Loss: 0.2084, Acc: 0.9185
# Evaluation Loss:0.1437, Acc: 0.9453
# ----Model saved!----
# Epoch [4/200], Loss: 0.1280, Acc: 0.9551
# Evaluation Loss:0.1112, Acc: 0.9464
# ----Model saved!----
# Epoch [5/200], Loss: 0.0683, Acc: 0.9810
# Evaluation Loss:0.0384, Acc: 0.9978
# ----Model saved!----
# Epoch [6/200], Loss: 0.0396, Acc: 0.9900
# Evaluation Loss:0.0189, Acc: 1.0000
# ----Model saved!----
# Epoch [7/200], Loss: 0.0177, Acc: 0.9992
# Evaluation Loss:0.0091, Acc: 1.0000
# Epoch [8/200], Loss: 0.0143, Acc: 0.9978
# Evaluation Loss:0.0098, Acc: 0.9989
# Epoch [9/200], Loss: 0.0104, Acc: 0.9994
# Evaluation Loss:0.0039, Acc: 1.0000
# Epoch [10/200], Loss: 0.0057, Acc: 0.9997
# Evaluation Loss:0.0018, Acc: 1.0000
# Epoch [11/200], Loss: 0.0054, Acc: 1.0000
# Evaluation Loss:0.0014, Acc: 1.0000
# ----Early stopping----
# Test Loss:1.4091, Acc: 0.5998
# Subject:0
# mACC: 0.57
# std: 0.10
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5474, Acc: 0.7009
# Evaluation Loss:0.4722, Acc: 0.7891
# ----Model saved!----
# Epoch [2/200], Loss: 0.3585, Acc: 0.8488
# Evaluation Loss:0.3554, Acc: 0.8304
# ----Model saved!----
# Epoch [3/200], Loss: 0.2543, Acc: 0.9090
# Evaluation Loss:0.2515, Acc: 0.8973
# ----Model saved!----
# Epoch [4/200], Loss: 0.1711, Acc: 0.9411
# Evaluation Loss:0.1606, Acc: 0.9453
# ----Model saved!----
# Epoch [5/200], Loss: 0.1054, Acc: 0.9688
# Evaluation Loss:0.1076, Acc: 0.9710
# ----Model saved!----
# Epoch [6/200], Loss: 0.0749, Acc: 0.9821
# Evaluation Loss:0.0762, Acc: 0.9821
# ----Model saved!----
# Epoch [7/200], Loss: 0.0436, Acc: 0.9925
# Evaluation Loss:0.0497, Acc: 0.9844
# ----Model saved!----
# Epoch [8/200], Loss: 0.0419, Acc: 0.9891
# Evaluation Loss:0.0476, Acc: 0.9821
# Epoch [9/200], Loss: 0.0273, Acc: 0.9947
# Evaluation Loss:0.0301, Acc: 0.9900
# ----Model saved!----
# Epoch [10/200], Loss: 0.0280, Acc: 0.9936
# Evaluation Loss:0.0211, Acc: 0.9944
# ----Model saved!----
# Epoch [11/200], Loss: 0.0132, Acc: 0.9992
# Evaluation Loss:0.0150, Acc: 0.9967
# ----Model saved!----
# Epoch [12/200], Loss: 0.0099, Acc: 0.9997
# Evaluation Loss:0.0099, Acc: 0.9955
# Epoch [13/200], Loss: 0.0085, Acc: 1.0000
# Evaluation Loss:0.0105, Acc: 0.9967
# Epoch [14/200], Loss: 0.0118, Acc: 0.9980
# Evaluation Loss:0.0167, Acc: 0.9933
# Epoch [15/200], Loss: 0.0110, Acc: 0.9980
# Evaluation Loss:0.0090, Acc: 0.9955
# Epoch [16/200], Loss: 0.0052, Acc: 1.0000
# Evaluation Loss:0.0060, Acc: 0.9989
# ----Model saved!----
# Epoch [17/200], Loss: 0.0052, Acc: 1.0000
# Evaluation Loss:0.0070, Acc: 0.9978
# Epoch [18/200], Loss: 0.0047, Acc: 1.0000
# Evaluation Loss:0.0060, Acc: 0.9978
# Epoch [19/200], Loss: 0.0039, Acc: 1.0000
# Evaluation Loss:0.0082, Acc: 0.9978
# Epoch [20/200], Loss: 0.0045, Acc: 0.9997
# Evaluation Loss:0.0076, Acc: 0.9967
# Epoch [21/200], Loss: 0.0096, Acc: 0.9978
# Evaluation Loss:0.0204, Acc: 0.9922
# ----Early stopping----
# Test Loss:3.4216, Acc: 0.5226
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5378, Acc: 0.7252
# Evaluation Loss:0.4396, Acc: 0.8125
# ----Model saved!----
# Epoch [2/200], Loss: 0.3516, Acc: 0.8491
# Evaluation Loss:0.3383, Acc: 0.8382
# ----Model saved!----
# Epoch [3/200], Loss: 0.2441, Acc: 0.9029
# Evaluation Loss:0.1908, Acc: 0.9353
# ----Model saved!----
# Epoch [4/200], Loss: 0.1531, Acc: 0.9467
# Evaluation Loss:0.1279, Acc: 0.9609
# ----Model saved!----
# Epoch [5/200], Loss: 0.0888, Acc: 0.9785
# Evaluation Loss:0.0701, Acc: 0.9844
# ----Model saved!----
# Epoch [6/200], Loss: 0.0710, Acc: 0.9802
# Evaluation Loss:0.0491, Acc: 0.9888
# ----Model saved!----
# Epoch [7/200], Loss: 0.0411, Acc: 0.9944
# Evaluation Loss:0.0303, Acc: 0.9978
# ----Model saved!----
# Epoch [8/200], Loss: 0.0364, Acc: 0.9922
# Evaluation Loss:0.0259, Acc: 0.9978
# Epoch [9/200], Loss: 0.0261, Acc: 0.9955
# Evaluation Loss:0.0178, Acc: 0.9978
# Epoch [10/200], Loss: 0.0217, Acc: 0.9969
# Evaluation Loss:0.0176, Acc: 0.9989
# ----Model saved!----
# Epoch [11/200], Loss: 0.0176, Acc: 0.9980
# Evaluation Loss:0.0184, Acc: 0.9989
# Epoch [12/200], Loss: 0.0189, Acc: 0.9978
# Evaluation Loss:0.0080, Acc: 1.0000
# ----Model saved!----
# Epoch [13/200], Loss: 0.0102, Acc: 0.9992
# Evaluation Loss:0.0060, Acc: 1.0000
# Epoch [14/200], Loss: 0.0150, Acc: 0.9967
# Evaluation Loss:0.0071, Acc: 1.0000
# Epoch [15/200], Loss: 0.0154, Acc: 0.9969
# Evaluation Loss:0.0081, Acc: 1.0000
# Epoch [16/200], Loss: 0.0210, Acc: 0.9939
# Evaluation Loss:0.0082, Acc: 0.9978
# Epoch [17/200], Loss: 0.0232, Acc: 0.9930
# Evaluation Loss:0.0225, Acc: 0.9911
# ----Early stopping----
# Test Loss:1.3703, Acc: 0.6849
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6378, Acc: 0.6264
# Evaluation Loss:0.5857, Acc: 0.6975
# ----Model saved!----
# Epoch [2/200], Loss: 0.5002, Acc: 0.7586
# Evaluation Loss:0.4551, Acc: 0.7734
# ----Model saved!----
# Epoch [3/200], Loss: 0.3670, Acc: 0.8451
# Evaluation Loss:0.3106, Acc: 0.8895
# ----Model saved!----
# Epoch [4/200], Loss: 0.2488, Acc: 0.9102
# Evaluation Loss:0.2729, Acc: 0.8761
# Epoch [5/200], Loss: 0.1805, Acc: 0.9355
# Evaluation Loss:0.1471, Acc: 0.9487
# ----Model saved!----
# Epoch [6/200], Loss: 0.1082, Acc: 0.9721
# Evaluation Loss:0.1026, Acc: 0.9766
# ----Model saved!----
# Epoch [7/200], Loss: 0.0686, Acc: 0.9877
# Evaluation Loss:0.0654, Acc: 0.9833
# ----Model saved!----
# Epoch [8/200], Loss: 0.0492, Acc: 0.9894
# Evaluation Loss:0.0424, Acc: 0.9933
# ----Model saved!----
# Epoch [9/200], Loss: 0.0377, Acc: 0.9941
# Evaluation Loss:0.0451, Acc: 0.9922
# Epoch [10/200], Loss: 0.0393, Acc: 0.9905
# Evaluation Loss:0.0222, Acc: 0.9989
# ----Model saved!----
# Epoch [11/200], Loss: 0.0284, Acc: 0.9947
# Evaluation Loss:0.0147, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0191, Acc: 0.9980
# Evaluation Loss:0.0129, Acc: 1.0000
# Epoch [13/200], Loss: 0.0169, Acc: 0.9980
# Evaluation Loss:0.0115, Acc: 1.0000
# Epoch [14/200], Loss: 0.0199, Acc: 0.9964
# Evaluation Loss:0.0133, Acc: 1.0000
# Epoch [15/200], Loss: 0.0227, Acc: 0.9953
# Evaluation Loss:0.0141, Acc: 1.0000
# Epoch [16/200], Loss: 0.0148, Acc: 0.9980
# Evaluation Loss:0.0090, Acc: 1.0000
# ----Early stopping----
# Test Loss:0.6027, Acc: 0.8255
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5450, Acc: 0.7104
# Evaluation Loss:0.4424, Acc: 0.7723
# ----Model saved!----
# Epoch [2/200], Loss: 0.3845, Acc: 0.8234
# Evaluation Loss:0.3574, Acc: 0.8281
# ----Model saved!----
# Epoch [3/200], Loss: 0.2937, Acc: 0.8853
# Evaluation Loss:0.2394, Acc: 0.9085
# ----Model saved!----
# Epoch [4/200], Loss: 0.2083, Acc: 0.9255
# Evaluation Loss:0.1608, Acc: 0.9576
# ----Model saved!----
# Epoch [5/200], Loss: 0.1331, Acc: 0.9607
# Evaluation Loss:0.0978, Acc: 0.9810
# ----Model saved!----
# Epoch [6/200], Loss: 0.1052, Acc: 0.9668
# Evaluation Loss:0.1467, Acc: 0.9353
# Epoch [7/200], Loss: 0.0754, Acc: 0.9807
# Evaluation Loss:0.0522, Acc: 0.9955
# ----Model saved!----
# Epoch [8/200], Loss: 0.0444, Acc: 0.9922
# Evaluation Loss:0.0280, Acc: 0.9978
# ----Model saved!----
# Epoch [9/200], Loss: 0.0300, Acc: 0.9964
# Evaluation Loss:0.0227, Acc: 1.0000
# ----Model saved!----
# Epoch [10/200], Loss: 0.0245, Acc: 0.9980
# Evaluation Loss:0.0217, Acc: 0.9967
# Epoch [11/200], Loss: 0.0190, Acc: 0.9980
# Evaluation Loss:0.0099, Acc: 0.9989
# Epoch [12/200], Loss: 0.0127, Acc: 0.9997
# Evaluation Loss:0.0083, Acc: 1.0000
# Epoch [13/200], Loss: 0.0111, Acc: 0.9989
# Evaluation Loss:0.0061, Acc: 1.0000
# Epoch [14/200], Loss: 0.0111, Acc: 0.9989
# Evaluation Loss:0.0073, Acc: 1.0000
# ----Early stopping----
# Test Loss:0.8357, Acc: 0.7847
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5324, Acc: 0.7174
# Evaluation Loss:0.4071, Acc: 0.8449
# ----Model saved!----
# Epoch [2/200], Loss: 0.2952, Acc: 0.8783
# Evaluation Loss:0.2477, Acc: 0.9018
# ----Model saved!----
# Epoch [3/200], Loss: 0.1786, Acc: 0.9372
# Evaluation Loss:0.1620, Acc: 0.9487
# ----Model saved!----
# Epoch [4/200], Loss: 0.0986, Acc: 0.9729
# Evaluation Loss:0.0855, Acc: 0.9721
# ----Model saved!----
# Epoch [5/200], Loss: 0.0524, Acc: 0.9902
# Evaluation Loss:0.0515, Acc: 0.9866
# ----Model saved!----
# Epoch [6/200], Loss: 0.0525, Acc: 0.9863
# Evaluation Loss:0.0436, Acc: 0.9888
# ----Model saved!----
# Epoch [7/200], Loss: 0.0364, Acc: 0.9922
# Evaluation Loss:0.0821, Acc: 0.9699
# Epoch [8/200], Loss: 0.0231, Acc: 0.9964
# Evaluation Loss:0.0153, Acc: 0.9978
# ----Model saved!----
# Epoch [9/200], Loss: 0.0137, Acc: 0.9992
# Evaluation Loss:0.0095, Acc: 0.9989
# ----Model saved!----
# Epoch [10/200], Loss: 0.0090, Acc: 0.9997
# Evaluation Loss:0.0072, Acc: 1.0000
# ----Model saved!----
# Epoch [11/200], Loss: 0.0071, Acc: 1.0000
# Evaluation Loss:0.0049, Acc: 1.0000
# Epoch [12/200], Loss: 0.0068, Acc: 0.9997
# Evaluation Loss:0.0051, Acc: 1.0000
# Epoch [13/200], Loss: 0.0077, Acc: 0.9994
# Evaluation Loss:0.0122, Acc: 0.9978
# Epoch [14/200], Loss: 0.0111, Acc: 0.9992
# Evaluation Loss:0.0084, Acc: 0.9989
# Epoch [15/200], Loss: 0.0091, Acc: 0.9989
# Evaluation Loss:0.0050, Acc: 0.9989
# ----Early stopping----
# Test Loss:4.3779, Acc: 0.4549
# Subject:1
# mACC: 0.65
# std: 0.14
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.4843, Acc: 0.7533
# Evaluation Loss:0.4023, Acc: 0.7891
# ----Model saved!----
# Epoch [2/200], Loss: 0.2398, Acc: 0.9007
# Evaluation Loss:0.2078, Acc: 0.9096
# ----Model saved!----
# Epoch [3/200], Loss: 0.1536, Acc: 0.9392
# Evaluation Loss:0.1347, Acc: 0.9542
# ----Model saved!----
# Epoch [4/200], Loss: 0.0990, Acc: 0.9657
# Evaluation Loss:0.0883, Acc: 0.9788
# ----Model saved!----
# Epoch [5/200], Loss: 0.0675, Acc: 0.9805
# Evaluation Loss:0.0588, Acc: 0.9821
# ----Model saved!----
# Epoch [6/200], Loss: 0.0375, Acc: 0.9927
# Evaluation Loss:0.0424, Acc: 0.9911
# ----Model saved!----
# Epoch [7/200], Loss: 0.0336, Acc: 0.9922
# Evaluation Loss:0.0399, Acc: 0.9900
# Epoch [8/200], Loss: 0.0311, Acc: 0.9922
# Evaluation Loss:0.0285, Acc: 0.9922
# ----Model saved!----
# Epoch [9/200], Loss: 0.0232, Acc: 0.9958
# Evaluation Loss:0.0132, Acc: 0.9967
# ----Model saved!----
# Epoch [10/200], Loss: 0.0194, Acc: 0.9969
# Evaluation Loss:0.0133, Acc: 0.9978
# ----Model saved!----
# Epoch [11/200], Loss: 0.0099, Acc: 0.9994
# Evaluation Loss:0.0053, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0061, Acc: 1.0000
# Evaluation Loss:0.0038, Acc: 1.0000
# Epoch [13/200], Loss: 0.0047, Acc: 1.0000
# Evaluation Loss:0.0035, Acc: 1.0000
# Epoch [14/200], Loss: 0.0049, Acc: 0.9997
# Evaluation Loss:0.0030, Acc: 1.0000
# Epoch [15/200], Loss: 0.0047, Acc: 1.0000
# Evaluation Loss:0.0021, Acc: 1.0000
# Epoch [16/200], Loss: 0.0048, Acc: 0.9994
# Evaluation Loss:0.0060, Acc: 1.0000
# ----Early stopping----
# Test Loss:4.7090, Acc: 0.6962
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6171, Acc: 0.6334
# Evaluation Loss:0.5727, Acc: 0.7545
# ----Model saved!----
# Epoch [2/200], Loss: 0.4788, Acc: 0.7787
# Evaluation Loss:0.4740, Acc: 0.7377
# Epoch [3/200], Loss: 0.3041, Acc: 0.8867
# Evaluation Loss:0.2993, Acc: 0.8694
# ----Model saved!----
# Epoch [4/200], Loss: 0.2752, Acc: 0.8881
# Evaluation Loss:0.2861, Acc: 0.8683
# Epoch [5/200], Loss: 0.1845, Acc: 0.9350
# Evaluation Loss:0.2016, Acc: 0.9118
# ----Model saved!----
# Epoch [6/200], Loss: 0.1311, Acc: 0.9540
# Evaluation Loss:0.2325, Acc: 0.8917
# Epoch [7/200], Loss: 0.1160, Acc: 0.9593
# Evaluation Loss:0.2269, Acc: 0.9007
# Epoch [8/200], Loss: 0.0877, Acc: 0.9732
# Evaluation Loss:0.1053, Acc: 0.9576
# ----Model saved!----
# Epoch [9/200], Loss: 0.0961, Acc: 0.9657
# Evaluation Loss:0.0743, Acc: 0.9721
# ----Model saved!----
# Epoch [10/200], Loss: 0.0552, Acc: 0.9863
# Evaluation Loss:0.1081, Acc: 0.9531
# Epoch [11/200], Loss: 0.0322, Acc: 0.9927
# Evaluation Loss:0.0641, Acc: 0.9777
# ----Model saved!----
# Epoch [12/200], Loss: 0.0279, Acc: 0.9939
# Evaluation Loss:0.0525, Acc: 0.9810
# ----Model saved!----
# Epoch [13/200], Loss: 0.0325, Acc: 0.9905
# Evaluation Loss:0.1671, Acc: 0.9375
# Epoch [14/200], Loss: 0.0401, Acc: 0.9866
# Evaluation Loss:0.1599, Acc: 0.9330
# Epoch [15/200], Loss: 0.0179, Acc: 0.9972
# Evaluation Loss:0.0502, Acc: 0.9788
# Epoch [16/200], Loss: 0.0132, Acc: 0.9983
# Evaluation Loss:0.0623, Acc: 0.9732
# Epoch [17/200], Loss: 0.0165, Acc: 0.9967
# Evaluation Loss:0.0247, Acc: 0.9911
# ----Model saved!----
# Epoch [18/200], Loss: 0.0273, Acc: 0.9911
# Evaluation Loss:0.0512, Acc: 0.9799
# Epoch [19/200], Loss: 0.0335, Acc: 0.9908
# Evaluation Loss:0.0924, Acc: 0.9665
# Epoch [20/200], Loss: 0.0118, Acc: 0.9992
# Evaluation Loss:0.0682, Acc: 0.9699
# Epoch [21/200], Loss: 0.0150, Acc: 0.9967
# Evaluation Loss:0.0677, Acc: 0.9699
# Epoch [22/200], Loss: 0.0110, Acc: 0.9983
# Evaluation Loss:0.0146, Acc: 0.9933
# ----Model saved!----
# Epoch [23/200], Loss: 0.0061, Acc: 0.9997
# Evaluation Loss:0.1032, Acc: 0.9542
# Epoch [24/200], Loss: 0.0064, Acc: 0.9997
# Evaluation Loss:0.0046, Acc: 1.0000
# ----Model saved!----
# Epoch [25/200], Loss: 0.0049, Acc: 1.0000
# Evaluation Loss:0.0034, Acc: 1.0000
# Epoch [26/200], Loss: 0.0065, Acc: 0.9992
# Evaluation Loss:0.0297, Acc: 0.9866
# Epoch [27/200], Loss: 0.0050, Acc: 0.9994
# Evaluation Loss:0.0353, Acc: 0.9810
# Epoch [28/200], Loss: 0.0053, Acc: 0.9994
# Evaluation Loss:0.0129, Acc: 0.9955
# Epoch [29/200], Loss: 0.0052, Acc: 0.9994
# Evaluation Loss:0.0095, Acc: 0.9989
# ----Early stopping----
# Test Loss:0.8853, Acc: 0.8461
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5738, Acc: 0.7020
# Evaluation Loss:0.5086, Acc: 0.7935
# ----Model saved!----
# Epoch [2/200], Loss: 0.3728, Acc: 0.8454
# Evaluation Loss:0.2954, Acc: 0.8929
# ----Model saved!----
# Epoch [3/200], Loss: 0.1801, Acc: 0.9344
# Evaluation Loss:0.1288, Acc: 0.9565
# ----Model saved!----
# Epoch [4/200], Loss: 0.0975, Acc: 0.9634
# Evaluation Loss:0.0916, Acc: 0.9643
# ----Model saved!----
# Epoch [5/200], Loss: 0.0553, Acc: 0.9827
# Evaluation Loss:0.0448, Acc: 0.9866
# ----Model saved!----
# Epoch [6/200], Loss: 0.0314, Acc: 0.9919
# Evaluation Loss:0.0416, Acc: 0.9833
# Epoch [7/200], Loss: 0.0260, Acc: 0.9939
# Evaluation Loss:0.0311, Acc: 0.9877
# ----Model saved!----
# Epoch [8/200], Loss: 0.0204, Acc: 0.9947
# Evaluation Loss:0.0140, Acc: 0.9955
# ----Model saved!----
# Epoch [9/200], Loss: 0.0159, Acc: 0.9964
# Evaluation Loss:0.0227, Acc: 0.9922
# Epoch [10/200], Loss: 0.0104, Acc: 0.9983
# Evaluation Loss:0.0039, Acc: 1.0000
# ----Model saved!----
# Epoch [11/200], Loss: 0.0055, Acc: 0.9994
# Evaluation Loss:0.0029, Acc: 1.0000
# Epoch [12/200], Loss: 0.0049, Acc: 0.9997
# Evaluation Loss:0.0025, Acc: 1.0000
# Epoch [13/200], Loss: 0.0044, Acc: 1.0000
# Evaluation Loss:0.0076, Acc: 0.9978
# Epoch [14/200], Loss: 0.0269, Acc: 0.9914
# Evaluation Loss:0.0539, Acc: 0.9766
# Epoch [15/200], Loss: 0.0287, Acc: 0.9908
# Evaluation Loss:0.0270, Acc: 0.9866
# ----Early stopping----
# Test Loss:11.6970, Acc: 0.0408
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5581, Acc: 0.7087
# Evaluation Loss:0.4701, Acc: 0.7969
# ----Model saved!----
# Epoch [2/200], Loss: 0.3536, Acc: 0.8516
# Evaluation Loss:0.2650, Acc: 0.8973
# ----Model saved!----
# Epoch [3/200], Loss: 0.2315, Acc: 0.9102
# Evaluation Loss:0.1987, Acc: 0.9431
# ----Model saved!----
# Epoch [4/200], Loss: 0.1941, Acc: 0.9277
# Evaluation Loss:0.1891, Acc: 0.9252
# Epoch [5/200], Loss: 0.1446, Acc: 0.9473
# Evaluation Loss:0.0992, Acc: 0.9676
# ----Model saved!----
# Epoch [6/200], Loss: 0.0935, Acc: 0.9662
# Evaluation Loss:0.0778, Acc: 0.9699
# ----Model saved!----
# Epoch [7/200], Loss: 0.0573, Acc: 0.9824
# Evaluation Loss:0.0550, Acc: 0.9788
# ----Model saved!----
# Epoch [8/200], Loss: 0.0370, Acc: 0.9905
# Evaluation Loss:0.0305, Acc: 0.9877
# ----Model saved!----
# Epoch [9/200], Loss: 0.0347, Acc: 0.9911
# Evaluation Loss:0.0279, Acc: 0.9944
# ----Model saved!----
# Epoch [10/200], Loss: 0.0312, Acc: 0.9883
# Evaluation Loss:0.0621, Acc: 0.9710
# Epoch [11/200], Loss: 0.0387, Acc: 0.9869
# Evaluation Loss:0.0211, Acc: 0.9944
# Epoch [12/200], Loss: 0.0173, Acc: 0.9964
# Evaluation Loss:0.0143, Acc: 0.9967
# ----Model saved!----
# Epoch [13/200], Loss: 0.0098, Acc: 0.9992
# Evaluation Loss:0.0163, Acc: 0.9955
# Epoch [14/200], Loss: 0.0164, Acc: 0.9958
# Evaluation Loss:0.0256, Acc: 0.9922
# Epoch [15/200], Loss: 0.0103, Acc: 0.9980
# Evaluation Loss:0.0048, Acc: 0.9989
# ----Model saved!----
# Epoch [16/200], Loss: 0.0107, Acc: 0.9986
# Evaluation Loss:0.0168, Acc: 0.9955
# Epoch [17/200], Loss: 0.0055, Acc: 1.0000
# Evaluation Loss:0.0037, Acc: 1.0000
# ----Model saved!----
# Epoch [18/200], Loss: 0.0048, Acc: 0.9997
# Evaluation Loss:0.0018, Acc: 1.0000
# Epoch [19/200], Loss: 0.0036, Acc: 1.0000
# Evaluation Loss:0.0029, Acc: 0.9989
# Epoch [20/200], Loss: 0.0029, Acc: 1.0000
# Evaluation Loss:0.0017, Acc: 1.0000
# Epoch [21/200], Loss: 0.0039, Acc: 0.9997
# Evaluation Loss:0.0041, Acc: 0.9989
# Epoch [22/200], Loss: 0.0031, Acc: 1.0000
# Evaluation Loss:0.0022, Acc: 1.0000
# ----Early stopping----
# Test Loss:2.5346, Acc: 0.5775
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5783, Acc: 0.6992
# Evaluation Loss:0.5050, Acc: 0.8025
# ----Model saved!----
# Epoch [2/200], Loss: 0.3656, Acc: 0.8393
# Evaluation Loss:0.2764, Acc: 0.8996
# ----Model saved!----
# Epoch [3/200], Loss: 0.1999, Acc: 0.9230
# Evaluation Loss:0.1551, Acc: 0.9397
# ----Model saved!----
# Epoch [4/200], Loss: 0.1657, Acc: 0.9305
# Evaluation Loss:0.2010, Acc: 0.9051
# Epoch [5/200], Loss: 0.1480, Acc: 0.9403
# Evaluation Loss:0.0648, Acc: 0.9855
# ----Model saved!----
# Epoch [6/200], Loss: 0.1182, Acc: 0.9556
# Evaluation Loss:0.0773, Acc: 0.9676
# Epoch [7/200], Loss: 0.0641, Acc: 0.9780
# Evaluation Loss:0.0525, Acc: 0.9888
# ----Model saved!----
# Epoch [8/200], Loss: 0.0560, Acc: 0.9802
# Evaluation Loss:0.0428, Acc: 0.9855
# Epoch [9/200], Loss: 0.0711, Acc: 0.9710
# Evaluation Loss:0.0856, Acc: 0.9520
# Epoch [10/200], Loss: 0.0450, Acc: 0.9849
# Evaluation Loss:0.0330, Acc: 0.9900
# ----Model saved!----
# Epoch [11/200], Loss: 0.0381, Acc: 0.9877
# Evaluation Loss:0.0379, Acc: 0.9844
# Epoch [12/200], Loss: 0.0215, Acc: 0.9941
# Evaluation Loss:0.0131, Acc: 1.0000
# ----Model saved!----
# Epoch [13/200], Loss: 0.0202, Acc: 0.9953
# Evaluation Loss:0.0267, Acc: 0.9911
# Epoch [14/200], Loss: 0.0302, Acc: 0.9908
# Evaluation Loss:0.1260, Acc: 0.9364
# Epoch [15/200], Loss: 0.0292, Acc: 0.9900
# Evaluation Loss:0.0071, Acc: 1.0000
# Epoch [16/200], Loss: 0.0369, Acc: 0.9900
# Evaluation Loss:0.0412, Acc: 0.9844
# Epoch [17/200], Loss: 0.0185, Acc: 0.9958
# Evaluation Loss:0.0340, Acc: 0.9866
# ----Early stopping----
# Test Loss:1.5958, Acc: 0.5492
# Subject:2
# mACC: 0.54
# std: 0.27
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6380, Acc: 0.6272
# Evaluation Loss:0.5820, Acc: 0.7254
# ----Model saved!----
# Epoch [2/200], Loss: 0.4930, Acc: 0.7631
# Evaluation Loss:0.4544, Acc: 0.7734
# ----Model saved!----
# Epoch [3/200], Loss: 0.3790, Acc: 0.8407
# Evaluation Loss:0.3171, Acc: 0.8839
# ----Model saved!----
# Epoch [4/200], Loss: 0.2711, Acc: 0.9001
# Evaluation Loss:0.2277, Acc: 0.9196
# ----Model saved!----
# Epoch [5/200], Loss: 0.1968, Acc: 0.9336
# Evaluation Loss:0.1689, Acc: 0.9475
# ----Model saved!----
# Epoch [6/200], Loss: 0.1447, Acc: 0.9573
# Evaluation Loss:0.1206, Acc: 0.9754
# ----Model saved!----
# Epoch [7/200], Loss: 0.1032, Acc: 0.9768
# Evaluation Loss:0.0885, Acc: 0.9821
# ----Model saved!----
# Epoch [8/200], Loss: 0.0810, Acc: 0.9824
# Evaluation Loss:0.0587, Acc: 0.9888
# ----Model saved!----
# Epoch [9/200], Loss: 0.0625, Acc: 0.9883
# Evaluation Loss:0.0456, Acc: 0.9933
# ----Model saved!----
# Epoch [10/200], Loss: 0.0475, Acc: 0.9908
# Evaluation Loss:0.0298, Acc: 0.9989
# ----Model saved!----
# Epoch [11/200], Loss: 0.0366, Acc: 0.9933
# Evaluation Loss:0.0261, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0323, Acc: 0.9950
# Evaluation Loss:0.0196, Acc: 0.9989
# Epoch [13/200], Loss: 0.0279, Acc: 0.9964
# Evaluation Loss:0.0137, Acc: 1.0000
# Epoch [14/200], Loss: 0.0246, Acc: 0.9967
# Evaluation Loss:0.0140, Acc: 1.0000
# Epoch [15/200], Loss: 0.0224, Acc: 0.9967
# Evaluation Loss:0.0105, Acc: 1.0000
# Epoch [16/200], Loss: 0.0187, Acc: 0.9978
# Evaluation Loss:0.0089, Acc: 1.0000
# ----Early stopping----
# Test Loss:2.6580, Acc: 0.6429
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6327, Acc: 0.6309
# Evaluation Loss:0.5949, Acc: 0.6908
# ----Model saved!----
# Epoch [2/200], Loss: 0.5365, Acc: 0.7266
# Evaluation Loss:0.5070, Acc: 0.7511
# ----Model saved!----
# Epoch [3/200], Loss: 0.4303, Acc: 0.8122
# Evaluation Loss:0.4173, Acc: 0.8214
# ----Model saved!----
# Epoch [4/200], Loss: 0.3180, Acc: 0.8786
# Evaluation Loss:0.3025, Acc: 0.8884
# ----Model saved!----
# Epoch [5/200], Loss: 0.2303, Acc: 0.9152
# Evaluation Loss:0.2591, Acc: 0.9062
# ----Model saved!----
# Epoch [6/200], Loss: 0.1689, Acc: 0.9453
# Evaluation Loss:0.1483, Acc: 0.9676
# ----Model saved!----
# Epoch [7/200], Loss: 0.1231, Acc: 0.9648
# Evaluation Loss:0.1343, Acc: 0.9643
# Epoch [8/200], Loss: 0.0856, Acc: 0.9807
# Evaluation Loss:0.0795, Acc: 0.9877
# ----Model saved!----
# Epoch [9/200], Loss: 0.0638, Acc: 0.9841
# Evaluation Loss:0.0642, Acc: 0.9877
# Epoch [10/200], Loss: 0.0508, Acc: 0.9905
# Evaluation Loss:0.0473, Acc: 0.9933
# ----Model saved!----
# Epoch [11/200], Loss: 0.0440, Acc: 0.9911
# Evaluation Loss:0.0416, Acc: 0.9922
# Epoch [12/200], Loss: 0.0343, Acc: 0.9933
# Evaluation Loss:0.0267, Acc: 0.9978
# ----Model saved!----
# Epoch [13/200], Loss: 0.0271, Acc: 0.9958
# Evaluation Loss:0.0214, Acc: 1.0000
# ----Model saved!----
# Epoch [14/200], Loss: 0.0206, Acc: 0.9989
# Evaluation Loss:0.0165, Acc: 0.9989
# Epoch [15/200], Loss: 0.0156, Acc: 0.9989
# Evaluation Loss:0.0177, Acc: 0.9989
# Epoch [16/200], Loss: 0.0204, Acc: 0.9955
# Evaluation Loss:0.0132, Acc: 0.9989
# Epoch [17/200], Loss: 0.0196, Acc: 0.9972
# Evaluation Loss:0.0211, Acc: 0.9944
# Epoch [18/200], Loss: 0.0162, Acc: 0.9978
# Evaluation Loss:0.0097, Acc: 0.9989
# ----Early stopping----
# Test Loss:1.3039, Acc: 0.5524
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6028, Acc: 0.6738
# Evaluation Loss:0.5628, Acc: 0.7411
# ----Model saved!----
# Epoch [2/200], Loss: 0.5040, Acc: 0.7586
# Evaluation Loss:0.4914, Acc: 0.7734
# ----Model saved!----
# Epoch [3/200], Loss: 0.4243, Acc: 0.8111
# Evaluation Loss:0.4121, Acc: 0.8315
# ----Model saved!----
# Epoch [4/200], Loss: 0.3290, Acc: 0.8697
# Evaluation Loss:0.3371, Acc: 0.8594
# ----Model saved!----
# Epoch [5/200], Loss: 0.2409, Acc: 0.9149
# Evaluation Loss:0.2344, Acc: 0.9241
# ----Model saved!----
# Epoch [6/200], Loss: 0.1696, Acc: 0.9442
# Evaluation Loss:0.1466, Acc: 0.9598
# ----Model saved!----
# Epoch [7/200], Loss: 0.1183, Acc: 0.9651
# Evaluation Loss:0.0948, Acc: 0.9833
# ----Model saved!----
# Epoch [8/200], Loss: 0.0762, Acc: 0.9819
# Evaluation Loss:0.0898, Acc: 0.9766
# Epoch [9/200], Loss: 0.0517, Acc: 0.9922
# Evaluation Loss:0.0367, Acc: 0.9967
# ----Model saved!----
# Epoch [10/200], Loss: 0.0329, Acc: 0.9955
# Evaluation Loss:0.0239, Acc: 0.9978
# ----Model saved!----
# Epoch [11/200], Loss: 0.0265, Acc: 0.9950
# Evaluation Loss:0.0252, Acc: 0.9978
# Epoch [12/200], Loss: 0.0253, Acc: 0.9955
# Evaluation Loss:0.0181, Acc: 0.9967
# Epoch [13/200], Loss: 0.0151, Acc: 0.9992
# Evaluation Loss:0.0101, Acc: 1.0000
# ----Model saved!----
# Epoch [14/200], Loss: 0.0128, Acc: 0.9989
# Evaluation Loss:0.0074, Acc: 1.0000
# Epoch [15/200], Loss: 0.0108, Acc: 0.9986
# Evaluation Loss:0.0049, Acc: 1.0000
# Epoch [16/200], Loss: 0.0102, Acc: 0.9992
# Evaluation Loss:0.0047, Acc: 1.0000
# Epoch [17/200], Loss: 0.0102, Acc: 0.9992
# Evaluation Loss:0.0048, Acc: 1.0000
# Epoch [18/200], Loss: 0.0099, Acc: 0.9992
# Evaluation Loss:0.0033, Acc: 1.0000
# ----Early stopping----
# Test Loss:2.8613, Acc: 0.5336
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6421, Acc: 0.6108
# Evaluation Loss:0.5988, Acc: 0.6875
# ----Model saved!----
# Epoch [2/200], Loss: 0.5359, Acc: 0.7341
# Evaluation Loss:0.5001, Acc: 0.7679
# ----Model saved!----
# Epoch [3/200], Loss: 0.4282, Acc: 0.8125
# Evaluation Loss:0.4042, Acc: 0.8415
# ----Model saved!----
# Epoch [4/200], Loss: 0.3349, Acc: 0.8658
# Evaluation Loss:0.3341, Acc: 0.8661
# ----Model saved!----
# Epoch [5/200], Loss: 0.2509, Acc: 0.9132
# Evaluation Loss:0.2582, Acc: 0.9085
# ----Model saved!----
# Epoch [6/200], Loss: 0.1925, Acc: 0.9339
# Evaluation Loss:0.1898, Acc: 0.9375
# ----Model saved!----
# Epoch [7/200], Loss: 0.1480, Acc: 0.9587
# Evaluation Loss:0.1440, Acc: 0.9609
# ----Model saved!----
# Epoch [8/200], Loss: 0.1081, Acc: 0.9699
# Evaluation Loss:0.0997, Acc: 0.9777
# ----Model saved!----
# Epoch [9/200], Loss: 0.0900, Acc: 0.9752
# Evaluation Loss:0.0804, Acc: 0.9810
# ----Model saved!----
# Epoch [10/200], Loss: 0.0627, Acc: 0.9891
# Evaluation Loss:0.0632, Acc: 0.9911
# ----Model saved!----
# Epoch [11/200], Loss: 0.0479, Acc: 0.9888
# Evaluation Loss:0.0421, Acc: 0.9933
# ----Model saved!----
# Epoch [12/200], Loss: 0.0374, Acc: 0.9944
# Evaluation Loss:0.0361, Acc: 0.9944
# ----Model saved!----
# Epoch [13/200], Loss: 0.0279, Acc: 0.9964
# Evaluation Loss:0.0287, Acc: 0.9955
# ----Model saved!----
# Epoch [14/200], Loss: 0.0237, Acc: 0.9969
# Evaluation Loss:0.0249, Acc: 0.9944
# Epoch [15/200], Loss: 0.0191, Acc: 0.9980
# Evaluation Loss:0.0265, Acc: 0.9944
# Epoch [16/200], Loss: 0.0164, Acc: 0.9992
# Evaluation Loss:0.0119, Acc: 0.9989
# ----Model saved!----
# Epoch [17/200], Loss: 0.0203, Acc: 0.9969
# Evaluation Loss:0.0313, Acc: 0.9911
# Epoch [18/200], Loss: 0.0189, Acc: 0.9969
# Evaluation Loss:0.0158, Acc: 0.9989
# Epoch [19/200], Loss: 0.0122, Acc: 0.9994
# Evaluation Loss:0.0085, Acc: 1.0000
# ----Model saved!----
# Epoch [20/200], Loss: 0.0135, Acc: 0.9986
# Evaluation Loss:0.0142, Acc: 0.9978
# Epoch [21/200], Loss: 0.0132, Acc: 0.9983
# Evaluation Loss:0.0257, Acc: 0.9933
# Epoch [22/200], Loss: 0.0177, Acc: 0.9975
# Evaluation Loss:0.0080, Acc: 1.0000
# Epoch [23/200], Loss: 0.0127, Acc: 0.9980
# Evaluation Loss:0.0140, Acc: 0.9955
# Epoch [24/200], Loss: 0.0095, Acc: 0.9992
# Evaluation Loss:0.0068, Acc: 1.0000
# ----Early stopping----
# Test Loss:1.4109, Acc: 0.6609
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6307, Acc: 0.6339
# Evaluation Loss:0.5940, Acc: 0.7310
# ----Model saved!----
# Epoch [2/200], Loss: 0.4811, Acc: 0.7974
# Evaluation Loss:0.4474, Acc: 0.8058
# ----Model saved!----
# Epoch [3/200], Loss: 0.3194, Acc: 0.8666
# Evaluation Loss:0.3210, Acc: 0.8426
# ----Model saved!----
# Epoch [4/200], Loss: 0.2179, Acc: 0.9185
# Evaluation Loss:0.1992, Acc: 0.9208
# ----Model saved!----
# Epoch [5/200], Loss: 0.1616, Acc: 0.9473
# Evaluation Loss:0.1417, Acc: 0.9509
# ----Model saved!----
# Epoch [6/200], Loss: 0.1146, Acc: 0.9584
# Evaluation Loss:0.0832, Acc: 0.9788
# ----Model saved!----
# Epoch [7/200], Loss: 0.0748, Acc: 0.9796
# Evaluation Loss:0.0667, Acc: 0.9877
# ----Model saved!----
# Epoch [8/200], Loss: 0.0473, Acc: 0.9883
# Evaluation Loss:0.0448, Acc: 0.9933
# ----Model saved!----
# Epoch [9/200], Loss: 0.0318, Acc: 0.9936
# Evaluation Loss:0.0382, Acc: 0.9911
# Epoch [10/200], Loss: 0.0243, Acc: 0.9950
# Evaluation Loss:0.0159, Acc: 0.9978
# ----Model saved!----
# Epoch [11/200], Loss: 0.0159, Acc: 0.9980
# Evaluation Loss:0.0125, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0105, Acc: 0.9997
# Evaluation Loss:0.0065, Acc: 1.0000
# Epoch [13/200], Loss: 0.0133, Acc: 0.9986
# Evaluation Loss:0.0070, Acc: 0.9989
# Epoch [14/200], Loss: 0.0106, Acc: 0.9989
# Evaluation Loss:0.0059, Acc: 1.0000
# Epoch [15/200], Loss: 0.0068, Acc: 1.0000
# Evaluation Loss:0.0040, Acc: 1.0000
# Epoch [16/200], Loss: 0.0053, Acc: 0.9997
# Evaluation Loss:0.0024, Acc: 1.0000
# ----Early stopping----
# Test Loss:13.9380, Acc: 0.5139
# Subject:3
# mACC: 0.58
# std: 0.06
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6226, Acc: 0.6264
# Evaluation Loss:0.5593, Acc: 0.7243
# ----Model saved!----
# Epoch [2/200], Loss: 0.5180, Acc: 0.7316
# Evaluation Loss:0.4321, Acc: 0.8237
# ----Model saved!----
# Epoch [3/200], Loss: 0.3144, Acc: 0.8652
# Evaluation Loss:0.2504, Acc: 0.8917
# ----Model saved!----
# Epoch [4/200], Loss: 0.2188, Acc: 0.9116
# Evaluation Loss:0.1820, Acc: 0.9196
# ----Model saved!----
# Epoch [5/200], Loss: 0.1471, Acc: 0.9453
# Evaluation Loss:0.1123, Acc: 0.9621
# ----Model saved!----
# Epoch [6/200], Loss: 0.0864, Acc: 0.9746
# Evaluation Loss:0.0598, Acc: 0.9844
# ----Model saved!----
# Epoch [7/200], Loss: 0.0460, Acc: 0.9908
# Evaluation Loss:0.0312, Acc: 0.9967
# ----Model saved!----
# Epoch [8/200], Loss: 0.0295, Acc: 0.9947
# Evaluation Loss:0.0349, Acc: 0.9900
# Epoch [9/200], Loss: 0.0234, Acc: 0.9950
# Evaluation Loss:0.0127, Acc: 0.9978
# ----Model saved!----
# Epoch [10/200], Loss: 0.0143, Acc: 0.9989
# Evaluation Loss:0.0085, Acc: 1.0000
# ----Model saved!----
# Epoch [11/200], Loss: 0.0146, Acc: 0.9969
# Evaluation Loss:0.0195, Acc: 0.9955
# Epoch [12/200], Loss: 0.0170, Acc: 0.9964
# Evaluation Loss:0.0064, Acc: 1.0000
# Epoch [13/200], Loss: 0.0081, Acc: 0.9994
# Evaluation Loss:0.0034, Acc: 1.0000
# Epoch [14/200], Loss: 0.0054, Acc: 0.9997
# Evaluation Loss:0.0034, Acc: 1.0000
# Epoch [15/200], Loss: 0.0045, Acc: 1.0000
# Evaluation Loss:0.0016, Acc: 1.0000
# ----Early stopping----
# Test Loss:0.0019, Acc: 1.0000
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5236, Acc: 0.6878
# Evaluation Loss:0.4500, Acc: 0.7846
# ----Model saved!----
# Epoch [2/200], Loss: 0.3596, Acc: 0.8329
# Evaluation Loss:0.2722, Acc: 0.9174
# ----Model saved!----
# Epoch [3/200], Loss: 0.1199, Acc: 0.9654
# Evaluation Loss:0.0838, Acc: 0.9754
# ----Model saved!----
# Epoch [4/200], Loss: 0.0736, Acc: 0.9766
# Evaluation Loss:0.0336, Acc: 0.9911
# ----Model saved!----
# Epoch [5/200], Loss: 0.0333, Acc: 0.9905
# Evaluation Loss:0.0190, Acc: 0.9989
# ----Model saved!----
# Epoch [6/200], Loss: 0.0186, Acc: 0.9955
# Evaluation Loss:0.0152, Acc: 0.9978
# Epoch [7/200], Loss: 0.0176, Acc: 0.9961
# Evaluation Loss:0.0142, Acc: 0.9978
# Epoch [8/200], Loss: 0.0131, Acc: 0.9975
# Evaluation Loss:0.0054, Acc: 1.0000
# ----Model saved!----
# Epoch [9/200], Loss: 0.0122, Acc: 0.9967
# Evaluation Loss:0.0040, Acc: 1.0000
# Epoch [10/200], Loss: 0.0147, Acc: 0.9953
# Evaluation Loss:0.0203, Acc: 0.9978
# Epoch [11/200], Loss: 0.0207, Acc: 0.9933
# Evaluation Loss:0.0105, Acc: 0.9989
# Epoch [12/200], Loss: 0.0108, Acc: 0.9975
# Evaluation Loss:0.0025, Acc: 1.0000
# Epoch [13/200], Loss: 0.0040, Acc: 1.0000
# Evaluation Loss:0.0017, Acc: 1.0000
# ----Early stopping----
# Test Loss:5.6474, Acc: 0.4861
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5278, Acc: 0.7006
# Evaluation Loss:0.4338, Acc: 0.8605
# ----Model saved!----
# Epoch [2/200], Loss: 0.3106, Acc: 0.8689
# Evaluation Loss:0.1987, Acc: 0.9453
# ----Model saved!----
# Epoch [3/200], Loss: 0.1076, Acc: 0.9665
# Evaluation Loss:0.0325, Acc: 0.9989
# ----Model saved!----
# Epoch [4/200], Loss: 0.0404, Acc: 0.9880
# Evaluation Loss:0.0199, Acc: 0.9967
# Epoch [5/200], Loss: 0.0261, Acc: 0.9961
# Evaluation Loss:0.0095, Acc: 1.0000
# ----Model saved!----
# Epoch [6/200], Loss: 0.0097, Acc: 0.9997
# Evaluation Loss:0.0045, Acc: 1.0000
# Epoch [7/200], Loss: 0.0091, Acc: 0.9992
# Evaluation Loss:0.0046, Acc: 1.0000
# Epoch [8/200], Loss: 0.0081, Acc: 0.9994
# Evaluation Loss:0.0026, Acc: 1.0000
# Epoch [9/200], Loss: 0.0059, Acc: 0.9997
# Evaluation Loss:0.0017, Acc: 1.0000
# Epoch [10/200], Loss: 0.0052, Acc: 0.9994
# Evaluation Loss:0.0023, Acc: 1.0000
# ----Early stopping----
# Test Loss:1.9474, Acc: 0.7101
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5206, Acc: 0.7003
# Evaluation Loss:0.4302, Acc: 0.7801
# ----Model saved!----
# Epoch [2/200], Loss: 0.3436, Acc: 0.8438
# Evaluation Loss:0.2896, Acc: 0.8594
# ----Model saved!----
# Epoch [3/200], Loss: 0.2312, Acc: 0.9110
# Evaluation Loss:0.2122, Acc: 0.9085
# ----Model saved!----
# Epoch [4/200], Loss: 0.2002, Acc: 0.9216
# Evaluation Loss:0.1927, Acc: 0.9096
# ----Model saved!----
# Epoch [5/200], Loss: 0.1624, Acc: 0.9403
# Evaluation Loss:0.1627, Acc: 0.9364
# ----Model saved!----
# Epoch [6/200], Loss: 0.1263, Acc: 0.9548
# Evaluation Loss:0.1283, Acc: 0.9565
# ----Model saved!----
# Epoch [7/200], Loss: 0.0968, Acc: 0.9704
# Evaluation Loss:0.0847, Acc: 0.9810
# ----Model saved!----
# Epoch [8/200], Loss: 0.0784, Acc: 0.9729
# Evaluation Loss:0.0586, Acc: 0.9866
# ----Model saved!----
# Epoch [9/200], Loss: 0.0397, Acc: 0.9905
# Evaluation Loss:0.0304, Acc: 0.9967
# ----Model saved!----
# Epoch [10/200], Loss: 0.0379, Acc: 0.9897
# Evaluation Loss:0.0361, Acc: 0.9900
# Epoch [11/200], Loss: 0.0580, Acc: 0.9791
# Evaluation Loss:0.0223, Acc: 0.9978
# ----Model saved!----
# Epoch [12/200], Loss: 0.0221, Acc: 0.9944
# Evaluation Loss:0.0091, Acc: 1.0000
# ----Model saved!----
# Epoch [13/200], Loss: 0.0084, Acc: 1.0000
# Evaluation Loss:0.0064, Acc: 0.9978
# Epoch [14/200], Loss: 0.0083, Acc: 0.9986
# Evaluation Loss:0.0066, Acc: 0.9978
# Epoch [15/200], Loss: 0.0063, Acc: 0.9997
# Evaluation Loss:0.0033, Acc: 1.0000
# Epoch [16/200], Loss: 0.0063, Acc: 0.9992
# Evaluation Loss:0.0019, Acc: 1.0000
# Epoch [17/200], Loss: 0.0041, Acc: 1.0000
# Evaluation Loss:0.0014, Acc: 1.0000
# ----Early stopping----
# Test Loss:2.8633, Acc: 0.4523
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5539, Acc: 0.6571
# Evaluation Loss:0.4991, Acc: 0.8125
# ----Model saved!----
# Epoch [2/200], Loss: 0.3691, Acc: 0.8429
# Evaluation Loss:0.2697, Acc: 0.8862
# ----Model saved!----
# Epoch [3/200], Loss: 0.1937, Acc: 0.9213
# Evaluation Loss:0.1940, Acc: 0.9208
# ----Model saved!----
# Epoch [4/200], Loss: 0.1558, Acc: 0.9347
# Evaluation Loss:0.1351, Acc: 0.9420
# ----Model saved!----
# Epoch [5/200], Loss: 0.0978, Acc: 0.9665
# Evaluation Loss:0.0684, Acc: 0.9788
# ----Model saved!----
# Epoch [6/200], Loss: 0.0589, Acc: 0.9796
# Evaluation Loss:0.0492, Acc: 0.9810
# ----Model saved!----
# Epoch [7/200], Loss: 0.0325, Acc: 0.9914
# Evaluation Loss:0.0232, Acc: 0.9967
# ----Model saved!----
# Epoch [8/200], Loss: 0.0187, Acc: 0.9967
# Evaluation Loss:0.0104, Acc: 0.9989
# ----Model saved!----
# Epoch [9/200], Loss: 0.0125, Acc: 0.9978
# Evaluation Loss:0.0099, Acc: 0.9989
# Epoch [10/200], Loss: 0.0077, Acc: 0.9992
# Evaluation Loss:0.0056, Acc: 0.9989
# Epoch [11/200], Loss: 0.0073, Acc: 0.9992
# Evaluation Loss:0.0021, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0057, Acc: 0.9997
# Evaluation Loss:0.0242, Acc: 0.9900
# Epoch [13/200], Loss: 0.0041, Acc: 1.0000
# Evaluation Loss:0.0013, Acc: 1.0000
# Epoch [14/200], Loss: 0.0049, Acc: 0.9997
# Evaluation Loss:0.0073, Acc: 0.9989
# Epoch [15/200], Loss: 0.0061, Acc: 0.9992
# Evaluation Loss:0.0014, Acc: 1.0000
# Epoch [16/200], Loss: 0.0047, Acc: 0.9997
# Evaluation Loss:0.0010, Acc: 1.0000
# ----Early stopping----
# Test Loss:4.0266, Acc: 0.5139
# Subject:4
# mACC: 0.63
# std: 0.20
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6525, Acc: 0.5968
# Evaluation Loss:0.6071, Acc: 0.6797
# ----Model saved!----
# Epoch [2/200], Loss: 0.5459, Acc: 0.7176
# Evaluation Loss:0.4927, Acc: 0.7835
# ----Model saved!----
# Epoch [3/200], Loss: 0.4388, Acc: 0.8058
# Evaluation Loss:0.3901, Acc: 0.8504
# ----Model saved!----
# Epoch [4/200], Loss: 0.3260, Acc: 0.8742
# Evaluation Loss:0.2930, Acc: 0.9062
# ----Model saved!----
# Epoch [5/200], Loss: 0.2388, Acc: 0.9174
# Evaluation Loss:0.2241, Acc: 0.9308
# ----Model saved!----
# Epoch [6/200], Loss: 0.1775, Acc: 0.9484
# Evaluation Loss:0.1569, Acc: 0.9554
# ----Model saved!----
# Epoch [7/200], Loss: 0.1202, Acc: 0.9724
# Evaluation Loss:0.1187, Acc: 0.9777
# ----Model saved!----
# Epoch [8/200], Loss: 0.0932, Acc: 0.9782
# Evaluation Loss:0.1029, Acc: 0.9732
# Epoch [9/200], Loss: 0.0656, Acc: 0.9880
# Evaluation Loss:0.0623, Acc: 0.9900
# ----Model saved!----
# Epoch [10/200], Loss: 0.0493, Acc: 0.9914
# Evaluation Loss:0.0440, Acc: 0.9967
# ----Model saved!----
# Epoch [11/200], Loss: 0.0419, Acc: 0.9922
# Evaluation Loss:0.0551, Acc: 0.9911
# Epoch [12/200], Loss: 0.0352, Acc: 0.9950
# Evaluation Loss:0.0375, Acc: 0.9944
# Epoch [13/200], Loss: 0.0274, Acc: 0.9967
# Evaluation Loss:0.0249, Acc: 1.0000
# ----Model saved!----
# Epoch [14/200], Loss: 0.0261, Acc: 0.9955
# Evaluation Loss:0.0287, Acc: 0.9944
# Epoch [15/200], Loss: 0.0195, Acc: 0.9980
# Evaluation Loss:0.0161, Acc: 0.9989
# Epoch [16/200], Loss: 0.0187, Acc: 0.9978
# Evaluation Loss:0.0146, Acc: 0.9989
# Epoch [17/200], Loss: 0.0135, Acc: 0.9992
# Evaluation Loss:0.0166, Acc: 0.9978
# Epoch [18/200], Loss: 0.0161, Acc: 0.9972
# Evaluation Loss:0.0113, Acc: 0.9978
# ----Early stopping----
# Test Loss:2.8073, Acc: 0.5434
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5979, Acc: 0.6733
# Evaluation Loss:0.5653, Acc: 0.7109
# ----Model saved!----
# Epoch [2/200], Loss: 0.4921, Acc: 0.7545
# Evaluation Loss:0.4759, Acc: 0.7779
# ----Model saved!----
# Epoch [3/200], Loss: 0.4172, Acc: 0.8139
# Evaluation Loss:0.4051, Acc: 0.8404
# ----Model saved!----
# Epoch [4/200], Loss: 0.3581, Acc: 0.8555
# Evaluation Loss:0.4665, Acc: 0.7589
# Epoch [5/200], Loss: 0.2948, Acc: 0.8836
# Evaluation Loss:0.2793, Acc: 0.9062
# ----Model saved!----
# Epoch [6/200], Loss: 0.2318, Acc: 0.9177
# Evaluation Loss:0.2383, Acc: 0.9219
# ----Model saved!----
# Epoch [7/200], Loss: 0.1767, Acc: 0.9461
# Evaluation Loss:0.1964, Acc: 0.9353
# ----Model saved!----
# Epoch [8/200], Loss: 0.1436, Acc: 0.9556
# Evaluation Loss:0.1266, Acc: 0.9688
# ----Model saved!----
# Epoch [9/200], Loss: 0.1078, Acc: 0.9710
# Evaluation Loss:0.1206, Acc: 0.9654
# Epoch [10/200], Loss: 0.0935, Acc: 0.9738
# Evaluation Loss:0.1057, Acc: 0.9676
# Epoch [11/200], Loss: 0.0701, Acc: 0.9844
# Evaluation Loss:0.0866, Acc: 0.9766
# ----Model saved!----
# Epoch [12/200], Loss: 0.0531, Acc: 0.9894
# Evaluation Loss:0.0938, Acc: 0.9665
# Epoch [13/200], Loss: 0.0448, Acc: 0.9905
# Evaluation Loss:0.0571, Acc: 0.9877
# ----Model saved!----
# Epoch [14/200], Loss: 0.0398, Acc: 0.9911
# Evaluation Loss:0.0435, Acc: 0.9900
# ----Model saved!----
# Epoch [15/200], Loss: 0.0328, Acc: 0.9950
# ...
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6334, Acc: 0.6309
# Evaluation Loss:0.5898, Acc: 0.7790
# ----Model saved!----
# Epoch [2/200], Loss: 0.4521, Acc: 0.8033
# Evaluation Loss:0.3561, Acc: 0.8460
# ----Model saved!----
# Epoch [3/200], Loss: 0.3139, Acc: 0.8700
# Evaluation Loss:0.3161, Acc: 0.8493
# ----Model saved!----
# Epoch [4/200], Loss: 0.2595, Acc: 0.8867
# Evaluation Loss:0.1973, Acc: 0.9219
# ----Model saved!----
# Epoch [5/200], Loss: 0.2024, Acc: 0.9230
# Evaluation Loss:0.1726, Acc: 0.9241
# ----Model saved!----
# Epoch [6/200], Loss: 0.1694, Acc: 0.9322
# Evaluation Loss:0.2518, Acc: 0.8750
# Epoch [7/200], Loss: 0.1564, Acc: 0.9403
# Evaluation Loss:0.1137, Acc: 0.9710
# ----Model saved!----
# Epoch [8/200], Loss: 0.0995, Acc: 0.9701
# Evaluation Loss:0.0935, Acc: 0.9721
# ----Model saved!----
# Epoch [9/200], Loss: 0.0840, Acc: 0.9713
# Evaluation Loss:0.0851, Acc: 0.9721
# Epoch [10/200], Loss: 0.0643, Acc: 0.9849
# Evaluation Loss:0.0531, Acc: 0.9866
# ----Model saved!----
# Epoch [11/200], Loss: 0.0495, Acc: 0.9874
# Evaluation Loss:0.0429, Acc: 0.9900
# ----Model saved!----
# Epoch [12/200], Loss: 0.0493, Acc: 0.9855
# Evaluation Loss:0.0502, Acc: 0.9877
# Epoch [13/200], Loss: 0.0360, Acc: 0.9930
# Evaluation Loss:0.0277, Acc: 0.9967
# ----Model saved!----
# Epoch [14/200], Loss: 0.0435, Acc: 0.9860
# Evaluation Loss:0.0417, Acc: 0.9922
# Epoch [15/200], Loss: 0.0442, Acc: 0.9860
# Evaluation Loss:0.0256, Acc: 0.9978
# ----Model saved!----
# Epoch [16/200], Loss: 0.0240, Acc: 0.9944
# Evaluation Loss:0.0155, Acc: 0.9989
# ----Model saved!----
# Epoch [17/200], Loss: 0.0212, Acc: 0.9964
# Evaluation Loss:0.0198, Acc: 0.9955
# Epoch [18/200], Loss: 0.0165, Acc: 0.9978
# Evaluation Loss:0.0103, Acc: 0.9978
# Epoch [19/200], Loss: 0.0180, Acc: 0.9958
# Evaluation Loss:0.0287, Acc: 0.9900
# Epoch [20/200], Loss: 0.0209, Acc: 0.9955
# Evaluation Loss:0.0155, Acc: 0.9978
# Epoch [21/200], Loss: 0.0192, Acc: 0.9944
# Evaluation Loss:0.0176, Acc: 0.9978
# ----Early stopping----
# Test Loss:3.7195, Acc: 0.4589
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6417, Acc: 0.6426
# Evaluation Loss:0.5686, Acc: 0.7746
# ----Model saved!----
# Epoch [2/200], Loss: 0.4703, Acc: 0.7927
# Evaluation Loss:0.3796, Acc: 0.8158
# ----Model saved!----
# Epoch [3/200], Loss: 0.3322, Acc: 0.8527
# Evaluation Loss:0.2579, Acc: 0.8817
# ----Model saved!----
# Epoch [4/200], Loss: 0.2347, Acc: 0.9032
# Evaluation Loss:0.2279, Acc: 0.8850
# ----Model saved!----
# Epoch [5/200], Loss: 0.1616, Acc: 0.9456
# Evaluation Loss:0.1349, Acc: 0.9554
# ----Model saved!----
# Epoch [6/200], Loss: 0.1243, Acc: 0.9579
# Evaluation Loss:0.1209, Acc: 0.9587
# ----Model saved!----
# Epoch [7/200], Loss: 0.0921, Acc: 0.9752
# Evaluation Loss:0.0626, Acc: 0.9911
# ----Model saved!----
# Epoch [8/200], Loss: 0.0736, Acc: 0.9810
# Evaluation Loss:0.0505, Acc: 0.9978
# ----Model saved!----
# Epoch [9/200], Loss: 0.0451, Acc: 0.9930
# Evaluation Loss:0.0337, Acc: 0.9989
# ----Model saved!----
# Epoch [10/200], Loss: 0.0345, Acc: 0.9961
# Evaluation Loss:0.0225, Acc: 1.0000
# ----Model saved!----
# Epoch [11/200], Loss: 0.0308, Acc: 0.9947
# Evaluation Loss:0.0486, Acc: 0.9844
# Epoch [12/200], Loss: 0.0360, Acc: 0.9919
# Evaluation Loss:0.0243, Acc: 0.9989
# Epoch [13/200], Loss: 0.0253, Acc: 0.9958
# Evaluation Loss:0.0185, Acc: 1.0000
# Epoch [14/200], Loss: 0.0202, Acc: 0.9978
# Evaluation Loss:0.0173, Acc: 0.9989
# Epoch [15/200], Loss: 0.0146, Acc: 0.9992
# Evaluation Loss:0.0095, Acc: 0.9989
# ----Early stopping----
# Test Loss:2.1030, Acc: 0.5298
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6190, Acc: 0.6484
# Evaluation Loss:0.5695, Acc: 0.7433
# ----Model saved!----
# Epoch [2/200], Loss: 0.4286, Acc: 0.8027
# Evaluation Loss:0.3864, Acc: 0.8225
# ----Model saved!----
# Epoch [3/200], Loss: 0.3213, Acc: 0.8527
# Evaluation Loss:0.2941, Acc: 0.8683
# ----Model saved!----
# Epoch [4/200], Loss: 0.2416, Acc: 0.9035
# Evaluation Loss:0.2108, Acc: 0.9051
# ----Model saved!----
# Epoch [5/200], Loss: 0.1671, Acc: 0.9353
# Evaluation Loss:0.1569, Acc: 0.9375
# ----Model saved!----
# Epoch [6/200], Loss: 0.1383, Acc: 0.9506
# Evaluation Loss:0.1619, Acc: 0.9286
# Epoch [7/200], Loss: 0.1043, Acc: 0.9646
# Evaluation Loss:0.1332, Acc: 0.9386
# ----Model saved!----
# Epoch [8/200], Loss: 0.1040, Acc: 0.9626
# Evaluation Loss:0.1288, Acc: 0.9475
# ----Model saved!----
# Epoch [9/200], Loss: 0.0678, Acc: 0.9802
# Evaluation Loss:0.1429, Acc: 0.9353
# Epoch [10/200], Loss: 0.0508, Acc: 0.9869
# Evaluation Loss:0.1715, Acc: 0.9208
# Epoch [11/200], Loss: 0.0380, Acc: 0.9927
# Evaluation Loss:0.1263, Acc: 0.9386
# Epoch [12/200], Loss: 0.0309, Acc: 0.9933
# Evaluation Loss:0.0502, Acc: 0.9833
# ----Model saved!----
# Epoch [13/200], Loss: 0.0267, Acc: 0.9958
# Evaluation Loss:0.1423, Acc: 0.9286
# Epoch [14/200], Loss: 0.0316, Acc: 0.9919
# Evaluation Loss:0.0388, Acc: 0.9922
# ----Model saved!----
# Epoch [15/200], Loss: 0.0246, Acc: 0.9958
# Evaluation Loss:0.0601, Acc: 0.9810
# Epoch [16/200], Loss: 0.0137, Acc: 0.9986
# Evaluation Loss:0.0826, Acc: 0.9621
# Epoch [17/200], Loss: 0.0172, Acc: 0.9978
# Evaluation Loss:0.0116, Acc: 1.0000
# ----Model saved!----
# Epoch [18/200], Loss: 0.0176, Acc: 0.9964
# Evaluation Loss:0.0833, Acc: 0.9654
# Epoch [19/200], Loss: 0.0133, Acc: 0.9978
# Evaluation Loss:0.0557, Acc: 0.9877
# Epoch [20/200], Loss: 0.0194, Acc: 0.9967
# Evaluation Loss:0.0714, Acc: 0.9721
# Epoch [21/200], Loss: 0.0190, Acc: 0.9944
# Evaluation Loss:0.0239, Acc: 0.9933
# Epoch [22/200], Loss: 0.0111, Acc: 0.9994
# Evaluation Loss:0.0461, Acc: 0.9810
# ----Early stopping----
# Test Loss:2.6198, Acc: 0.4416
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6454, Acc: 0.6085
# Evaluation Loss:0.6103, Acc: 0.6797
# ----Model saved!----
# Epoch [2/200], Loss: 0.5080, Acc: 0.7704
# Evaluation Loss:0.4913, Acc: 0.7411
# ----Model saved!----
# Epoch [3/200], Loss: 0.3954, Acc: 0.8158
# Evaluation Loss:0.3802, Acc: 0.8147
# ----Model saved!----
# Epoch [4/200], Loss: 0.3188, Acc: 0.8610
# Evaluation Loss:0.3243, Acc: 0.8571
# ----Model saved!----
# Epoch [5/200], Loss: 0.2761, Acc: 0.8775
# Evaluation Loss:0.2802, Acc: 0.8817
# ----Model saved!----
# Epoch [6/200], Loss: 0.2138, Acc: 0.9157
# Evaluation Loss:0.2536, Acc: 0.8906
# ----Model saved!----
# Epoch [7/200], Loss: 0.1637, Acc: 0.9448
# Evaluation Loss:0.1897, Acc: 0.9230
# ----Model saved!----
# Epoch [8/200], Loss: 0.1243, Acc: 0.9576
# Evaluation Loss:0.2605, Acc: 0.8806
# Epoch [9/200], Loss: 0.1122, Acc: 0.9643
# Evaluation Loss:0.1451, Acc: 0.9542
# ----Model saved!----
# Epoch [10/200], Loss: 0.0874, Acc: 0.9729
# Evaluation Loss:0.3759, Acc: 0.8527
# Epoch [11/200], Loss: 0.0706, Acc: 0.9791
# Evaluation Loss:0.1673, Acc: 0.9252
# Epoch [12/200], Loss: 0.0416, Acc: 0.9933
# Evaluation Loss:0.1253, Acc: 0.9531
# Epoch [13/200], Loss: 0.0404, Acc: 0.9916
# Evaluation Loss:0.1452, Acc: 0.9431
# Epoch [14/200], Loss: 0.0390, Acc: 0.9891
# Evaluation Loss:0.2025, Acc: 0.9129
# ----Early stopping----
# Test Loss:4.8002, Acc: 0.5156
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6550, Acc: 0.5918
# Evaluation Loss:0.6300, Acc: 0.6752
# ----Model saved!----
# Epoch [2/200], Loss: 0.5506, Acc: 0.7455
# Evaluation Loss:0.5364, Acc: 0.7288
# ----Model saved!----
# Epoch [3/200], Loss: 0.4649, Acc: 0.8002
# Evaluation Loss:0.4762, Acc: 0.7723
# ----Model saved!----
# Epoch [4/200], Loss: 0.4032, Acc: 0.8217
# Evaluation Loss:0.3943, Acc: 0.8270
# ----Model saved!----
# Epoch [5/200], Loss: 0.3249, Acc: 0.8661
# Evaluation Loss:0.3632, Acc: 0.8504
# ----Model saved!----
# Epoch [6/200], Loss: 0.2602, Acc: 0.8945
# Evaluation Loss:0.3242, Acc: 0.8504
# Epoch [7/200], Loss: 0.2047, Acc: 0.9252
# Evaluation Loss:0.2843, Acc: 0.8895
# ----Model saved!----
# Epoch [8/200], Loss: 0.1701, Acc: 0.9347
# Evaluation Loss:0.2429, Acc: 0.8984
# ----Model saved!----
# Epoch [9/200], Loss: 0.1313, Acc: 0.9618
# Evaluation Loss:0.2897, Acc: 0.8728
# Epoch [10/200], Loss: 0.0945, Acc: 0.9749
# Evaluation Loss:0.2615, Acc: 0.8906
# Epoch [11/200], Loss: 0.0813, Acc: 0.9780
# Evaluation Loss:0.2249, Acc: 0.9208
# ----Model saved!----
# Epoch [12/200], Loss: 0.0652, Acc: 0.9849
# Evaluation Loss:0.1439, Acc: 0.9498
# ----Model saved!----
# Epoch [13/200], Loss: 0.0512, Acc: 0.9900
# Evaluation Loss:0.2839, Acc: 0.8873
# Epoch [14/200], Loss: 0.0665, Acc: 0.9821
# Evaluation Loss:0.1244, Acc: 0.9665
# ----Model saved!----
# Epoch [15/200], Loss: 0.0516, Acc: 0.9869
# Evaluation Loss:0.1434, Acc: 0.9498
# Epoch [16/200], Loss: 0.0398, Acc: 0.9914
# Evaluation Loss:0.0961, Acc: 0.9732
# ----Model saved!----
# Epoch [17/200], Loss: 0.0254, Acc: 0.9955
# Evaluation Loss:0.1310, Acc: 0.9576
# Epoch [18/200], Loss: 0.0196, Acc: 0.9978
# Evaluation Loss:0.1818, Acc: 0.9330
# Epoch [19/200], Loss: 0.0149, Acc: 0.9994
# Evaluation Loss:0.1839, Acc: 0.9353
# Epoch [20/200], Loss: 0.0209, Acc: 0.9967
# Evaluation Loss:0.2835, Acc: 0.8973
# Epoch [21/200], Loss: 0.0362, Acc: 0.9891
# Evaluation Loss:0.1080, Acc: 0.9632
# ----Early stopping----
# Test Loss:2.4381, Acc: 0.5046
# Subject:13
# mACC: 0.49
# std: 0.03
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6739, Acc: 0.5725
# Evaluation Loss:0.6449, Acc: 0.6306
# ----Model saved!----
# Epoch [2/200], Loss: 0.5426, Acc: 0.7266
# Evaluation Loss:0.5915, Acc: 0.6763
# ----Model saved!----
# Epoch [3/200], Loss: 0.3245, Acc: 0.8666
# Evaluation Loss:0.2342, Acc: 0.9129
# ----Model saved!----
# Epoch [4/200], Loss: 0.1321, Acc: 0.9570
# Evaluation Loss:0.0695, Acc: 0.9855
# ----Model saved!----
# Epoch [5/200], Loss: 0.0550, Acc: 0.9866
# Evaluation Loss:0.0471, Acc: 0.9855
# Epoch [6/200], Loss: 0.0260, Acc: 0.9967
# Evaluation Loss:0.0114, Acc: 0.9989
# ----Model saved!----
# Epoch [7/200], Loss: 0.0131, Acc: 0.9980
# Evaluation Loss:0.0143, Acc: 0.9955
# Epoch [8/200], Loss: 0.0123, Acc: 0.9983
# Evaluation Loss:0.0149, Acc: 0.9967
# Epoch [9/200], Loss: 0.0077, Acc: 0.9994
# Evaluation Loss:0.0110, Acc: 0.9978
# Epoch [10/200], Loss: 0.0053, Acc: 1.0000
# Evaluation Loss:0.0091, Acc: 0.9989
# Epoch [11/200], Loss: 0.0038, Acc: 1.0000
# Evaluation Loss:0.0029, Acc: 1.0000
# ----Model saved!----
# Epoch [12/200], Loss: 0.0031, Acc: 1.0000
# Evaluation Loss:0.0015, Acc: 1.0000
# Epoch [13/200], Loss: 0.0027, Acc: 1.0000
# Evaluation Loss:0.0011, Acc: 1.0000
# Epoch [14/200], Loss: 0.0024, Acc: 1.0000
# Evaluation Loss:0.0009, Acc: 1.0000
# Epoch [15/200], Loss: 0.0024, Acc: 1.0000
# Evaluation Loss:0.0009, Acc: 1.0000
# Epoch [16/200], Loss: 0.0021, Acc: 1.0000
# Evaluation Loss:0.0006, Acc: 1.0000
# ----Early stopping----
# Test Loss:7.0209, Acc: 0.1696
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6613, Acc: 0.5818
# Evaluation Loss:0.6155, Acc: 0.6685
# ----Model saved!----
# Epoch [2/200], Loss: 0.4945, Acc: 0.7506
# Evaluation Loss:0.4168, Acc: 0.8705
# ----Model saved!----
# Epoch [3/200], Loss: 0.2825, Acc: 0.8864
# Evaluation Loss:0.1708, Acc: 0.9554
# ----Model saved!----
# Epoch [4/200], Loss: 0.0924, Acc: 0.9724
# Evaluation Loss:0.0551, Acc: 0.9855
# ----Model saved!----
# Epoch [5/200], Loss: 0.0286, Acc: 0.9964
# Evaluation Loss:0.0146, Acc: 0.9955
# ----Model saved!----
# Epoch [6/200], Loss: 0.0137, Acc: 0.9989
# Evaluation Loss:0.0139, Acc: 0.9978
# ----Model saved!----
# Epoch [7/200], Loss: 0.0076, Acc: 0.9997
# Evaluation Loss:0.0027, Acc: 1.0000
# ----Model saved!----
# Epoch [8/200], Loss: 0.0042, Acc: 1.0000
# Evaluation Loss:0.0078, Acc: 0.9989
# Epoch [9/200], Loss: 0.0035, Acc: 1.0000
# Evaluation Loss:0.0012, Acc: 1.0000
# Epoch [10/200], Loss: 0.0026, Acc: 1.0000
# Evaluation Loss:0.0010, Acc: 1.0000
# Epoch [11/200], Loss: 0.0026, Acc: 1.0000
# Evaluation Loss:0.0008, Acc: 1.0000
# Epoch [12/200], Loss: 0.0024, Acc: 1.0000
# Evaluation Loss:0.0007, Acc: 1.0000
# ----Early stopping----
# Test Loss:3.2656, Acc: 0.4852
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6370, Acc: 0.6044
# Evaluation Loss:0.6259, Acc: 0.5703
# ----Model saved!----
# Epoch [2/200], Loss: 0.4629, Acc: 0.7550
# Evaluation Loss:0.4242, Acc: 0.7712
# ----Model saved!----
# Epoch [3/200], Loss: 0.3024, Acc: 0.8544
# Evaluation Loss:0.2455, Acc: 0.8951
# ----Model saved!----
# Epoch [4/200], Loss: 0.1753, Acc: 0.9322
# Evaluation Loss:0.0927, Acc: 0.9766
# ----Model saved!----
# Epoch [5/200], Loss: 0.0867, Acc: 0.9763
# Evaluation Loss:0.0696, Acc: 0.9777
# ----Model saved!----
# Epoch [6/200], Loss: 0.0392, Acc: 0.9919
# Evaluation Loss:0.0464, Acc: 0.9844
# ----Model saved!----
# Epoch [7/200], Loss: 0.0213, Acc: 0.9955
# Evaluation Loss:0.0077, Acc: 1.0000
# ----Model saved!----
# Epoch [8/200], Loss: 0.0096, Acc: 0.9997
# Evaluation Loss:0.0241, Acc: 0.9944
# Epoch [9/200], Loss: 0.0065, Acc: 0.9997
# Evaluation Loss:0.0031, Acc: 1.0000
# Epoch [10/200], Loss: 0.0048, Acc: 1.0000
# Evaluation Loss:0.0028, Acc: 1.0000
# Epoch [11/200], Loss: 0.0046, Acc: 1.0000
# Evaluation Loss:0.0020, Acc: 1.0000
# Epoch [12/200], Loss: 0.0079, Acc: 0.9986
# Evaluation Loss:0.0060, Acc: 1.0000
# ----Early stopping----
# Test Loss:2.7208, Acc: 0.6195
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.5147, Acc: 0.7285
# Evaluation Loss:0.4203, Acc: 0.8203
# ----Model saved!----
# Epoch [2/200], Loss: 0.1914, Acc: 0.9191
# Evaluation Loss:0.1938, Acc: 0.9051
# ----Model saved!----
# Epoch [3/200], Loss: 0.0612, Acc: 0.9802
# Evaluation Loss:0.0369, Acc: 0.9866
# ----Model saved!----
# Epoch [4/200], Loss: 0.0242, Acc: 0.9950
# Evaluation Loss:0.0158, Acc: 0.9967
# ----Model saved!----
# Epoch [5/200], Loss: 0.0126, Acc: 0.9986
# Evaluation Loss:0.0091, Acc: 1.0000
# ----Model saved!----
# Epoch [6/200], Loss: 0.0050, Acc: 1.0000
# Evaluation Loss:0.0022, Acc: 1.0000
# Epoch [7/200], Loss: 0.0039, Acc: 1.0000
# Evaluation Loss:0.0012, Acc: 1.0000
# Epoch [8/200], Loss: 0.0026, Acc: 1.0000
# Evaluation Loss:0.0024, Acc: 1.0000
# Epoch [9/200], Loss: 0.0025, Acc: 1.0000
# Evaluation Loss:0.0005, Acc: 1.0000
# Epoch [10/200], Loss: 0.0022, Acc: 1.0000
# Evaluation Loss:0.0004, Acc: 1.0000
# ----Early stopping----
# Test Loss:14.5679, Acc: 0.4470
# Training: torch.Size([3584, 1, 4, 1024]) torch.Size([3584])
# Validation: torch.Size([896, 1, 4, 1024]) torch.Size([896])
# Test: torch.Size([1120, 1, 4, 1024]) torch.Size([1120])
# Avaliable device:Tesla K80
# Epoch [1/200], Loss: 0.6126, Acc: 0.6336
# Evaluation Loss:0.6174, Acc: 0.5491
# ----Model saved!----
# Epoch [2/200], Loss: 0.3060, Acc: 0.8750
# Evaluation Loss:0.2170, Acc: 0.9219
# ----Model saved!----
# Epoch [3/200], Loss: 0.0997, Acc: 0.9718
# Evaluation Loss:0.0551, Acc: 0.9866
# ----Model saved!----
# Epoch [4/200], Loss: 0.0375, Acc: 0.9914
# Evaluation Loss:0.0137, Acc: 1.0000
# ----Model saved!----
# Epoch [5/200], Loss: 0.0118, Acc: 0.9980
# Evaluation Loss:0.0035, Acc: 1.0000
# Epoch [6/200], Loss: 0.0067, Acc: 1.0000
# Evaluation Loss:0.0023, Acc: 1.0000
# Epoch [7/200], Loss: 0.0043, Acc: 1.0000
# Evaluation Loss:0.0016, Acc: 1.0000
# Epoch [8/200], Loss: 0.0032, Acc: 1.0000
# Evaluation Loss:0.0013, Acc: 1.0000
# Epoch [9/200], Loss: 0.0035, Acc: 0.9997
# Evaluation Loss:0.0084, Acc: 1.0000
# ----Early stopping----
# Test Loss:3.0109, Acc: 0.4870
# Subject:14
# mACC: 0.44
# std: 0.15
# Mean ACC:0.6027083333333334 Std:0.108642244246607
